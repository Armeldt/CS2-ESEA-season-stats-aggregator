# %%
import pandas as pd
import numpy as np
from demoparser2 import DemoParser

# %%
demo1 = DemoParser("VS_KREATURES_Anubis.dem")
demo2 = DemoParser("VS_Eldsjalar_Vertigo.dem")

# %% [markdown]
# ## Data prep

# %%
max_tick = demo1.parse_event("round_end")["tick"].max()

# %% [markdown]
# #### Test des différents parsers

# %%
event_df = demo1.parse_event("player_death", player=["X", "Y"], other=["total_rounds_played"])
all_events = demo1.parse_events(["all"])
ticks_df = demo1.parse_ticks(["X", "Y"])
stats = demo1.parse_grenades

# %%
# pd.set_option('display.max_rows', None)
pd.reset_option('display.max_rows')

# %%
ticks_df
# Out:
#              X       Y    tick            steamid          name
# 0       -400.0  2192.0       0  76561198111191178     -silentGG
# 1       -240.0 -1696.0       0  76561198264064168  JustAnotherL
# 2       -476.0  2216.0       0  76561198066661071      OzzieOzz
# 3       -608.0  2120.0       0  76561198259827471    godofbaldz
# 4       -192.0 -1608.0       0  76561199198706117    ADEODATUSS
# ...        ...     ...     ...                ...           ...
# 2450495    NaN     NaN  245185  76561198376612283     BELDIYA00
# 2450496    NaN     NaN  245185  76561198014090099        fykseN
# 2450497    NaN     NaN  245185  76561198358546254      MasaIDK_
# 2450498    NaN     NaN  245185  76561198173360875      Spiritix
# 2450499    NaN     NaN  245185  76561199074956403   3PARABELLUM
#
# [2450500 rows x 5 columns]

# %%
all_events
# Out:
# [('buytime_ended',
#         tick
#   0     2560
#   1     6214
#   2    11695
#   3    19886
#   4    24301
#   5    29174
#   6    35199
#   7    43633
#   8    50418
#   9    60253
#   10   66150
#   11   70697
#   12   79625
#   13   88409
#   14   93254
#   15  101145
#   16  110082
#   17  115819
#   18  125053
#   19  133389
#   20  141535
#   21  149136
#   22  159376
#   23  170539
#   24  181613
#   25  188256
#   26  196610
#   27  204986
#   28  214270
#   29  222846
#   30  231970),
#  ('round_mvp',
#       musickitid  musickitmvps  nomusic  reason    tick     user_name  \
#   0           40             0        0       1    2498  JustAnotherL
#   1           70             0        0       3    8686   3PARABELLUM
#   2            0             0        0       1   14957      OzzieOzz
#   3            0             0        0       1   21292      Spiritix
#   4            0             0        0       1   26165    godofbaldz
#   5           40             0        0       1   32190  JustAnotherL
#   6            0             0        1       2   40624      OzzieOzz
#   7            0             0        0       1   47409    ADEODATUSS
#   8           70             0        1       2   57244     -silentGG
#   9           70             0        0       1   63141     -silentGG
#   10          70             0        0       1   67688     BELDIYA00
#   11          70             0        0       9   76616     BELDIYA00
#   12           0             0        0       1   84888      Spiritix
#   13          70             0        0       1   90245   3PARABELLUM
#   14           0             0        0       1   98136      MasaIDK_
#   15           0             0        0       1  107073      MasaIDK_
#   16          70             0        0       1  112810   3PARABELLUM
#   17           0             0        1       2  122044      MasaIDK_
#   18           0             0        0       1  130380    ADEODATUSS
#   19           0             0        0       1  138526    ADEODATUSS
#   20          70             0        0       1  146127     BELDIYA00
#   21          40             0        1       2  156367  JustAnotherL
#   22          70             0        0       1  164535     -silentGG
#   23           0             0        0       3  175678    godofbaldz
#   24          70             0        0       1  184735   3PARABELLUM
#   25           0             0        0       1  193601      OzzieOzz
#   26          40             0        0       1  201977  JustAnotherL
#   27          70             0        0       1  210749        fykseN
#   28          70             0        0       1  219837     BELDIYA00
#   29           0             0        0       1  228961      OzzieOzz
#   30           0             0        0       1  236075    godofbaldz
#
#            user_steamid  value
#   0   76561198264064168      0
#   1   76561199074956403      0
#   2   76561198066661071      0
#   3   76561198173360875      0
#   4   76561198259827471      0
#   5   76561198264064168      0
#   6   76561198066661071      0
#   7   76561199198706117      0
#   8   76561198111191178      0
#   9   76561198111191178      0
#   10  76561198376612283      0
#   11  76561198376612283      0
#   12  76561198173360875      0
#   13  76561199074956403      0
#   14  76561198358546254      0
#   15  76561198358546254      0
#   16  76561199074956403      0
#   17  76561198358546254      0
#   18  76561199198706117      0
#   19  76561199198706117      0
#   20  76561198376612283      0
#   21  76561198264064168      0
#   22  76561198111191178      0
#   23  76561198259827471      0
#   24  76561199074956403      0
#   25  76561198066661071      0
#   26  76561198264064168      0
#   27  76561198014090099      0
#   28  76561198376612283      0
#   29  76561198066661071      0
#   30  76561198259827471      0  ),
#  ('round_prestart',
#         tick
#   0        0
#   1     2676
#   2     3120
#   3     3237
#   4     9134
#   5    15405
#   6    21740
#   7    26613
#   8    32638
#   9    41072
#   10   47857
#   11   57692
#   12   63589
#   13   68136
#   14   77064
#   15   85432
#   16   90693
#   17   98584
#   18  107521
#   19  113258
#   20  122492
#   21  130828
#   22  138974
#   23  146575
#   24  156815
#   25  164983
#   26  176126
#   27  185279
#   28  194049
#   29  202425
#   30  211293
#   31  220285
#   32  229409),
#  ('bomb_dropped',
#       entindex    tick     user_name       user_steamid
#   0        811   18870     -silentGG  76561198111191178
#   1        420   22676    godofbaldz  76561198259827471
#   2        243   27647      Spiritix  76561198173360875
#   3        243   27831    godofbaldz  76561198259827471
#   4        243   32190     BELDIYA00  76561198376612283
#   5        861   33466     BELDIYA00  76561198376612283
#   6        226   44634      OzzieOzz  76561198066661071
#   7        226   47409      Spiritix  76561198173360875
#   8        326   49430     -silentGG  76561198111191178
#   9        672   65113      Spiritix  76561198173360875
#   10       450   78790      OzzieOzz  76561198066661071
#   11       755   87188   3PARABELLUM  76561199074956403
#   12       755   87313        fykseN  76561198014090099
#   13       152   92398    ADEODATUSS  76561199198706117
#   14       226   99152        fykseN  76561198014090099
#   15       226  101215        fykseN  76561198014090099
#   16       226  106330        fykseN  76561198014090099
#   17       797  109368  JustAnotherL  76561198264064168
#   18       797  109926  JustAnotherL  76561198264064168
#   19      1004  113673      MasaIDK_  76561198358546254
#   20      1004  113847   3PARABELLUM  76561199074956403
#   21      1004  114774      MasaIDK_  76561198358546254
#   22       346  124162   3PARABELLUM  76561199074956403
#   23       200  132353    ADEODATUSS  76561199198706117
#   24       532  139528        fykseN  76561198014090099
#   25       532  140493    ADEODATUSS  76561199198706117
#   26       532  145456      MasaIDK_  76561198358546254
#   27       149  148488  JustAnotherL  76561198264064168
#   28       149  152721      MasaIDK_  76561198358546254
#   29       736  158338      MasaIDK_  76561198358546254
#   30       736  158556        fykseN  76561198014090099
#   31       736  164535  JustAnotherL  76561198264064168
#   32       877  166426   3PARABELLUM  76561199074956403
#   33       877  169547    ADEODATUSS  76561199198706117
#   34       877  169917      MasaIDK_  76561198358546254
#   35       877  172005      MasaIDK_  76561198358546254
#   36       719  176891    ADEODATUSS  76561199198706117
#   37       719  182667      MasaIDK_  76561198358546254
#   38       258  186536        fykseN  76561198014090099
#   39       258  187523  JustAnotherL  76561198264064168
#   40       258  187816      MasaIDK_  76561198358546254
#   41       258  193324        fykseN  76561198014090099
#   42       910  195972  JustAnotherL  76561198264064168
#   43       910  199972   3PARABELLUM  76561199074956403
#   44       474  204001      MasaIDK_  76561198358546254
#   45       474  206297        fykseN  76561198014090099
#   46       864  212276     -silentGG  76561198111191178
#   47       864  213509      Spiritix  76561198173360875
#   48      1006  221270    godofbaldz  76561198259827471
#   49      1006  221937     BELDIYA00  76561198376612283
#   50      1006  226675    godofbaldz  76561198259827471
#   51       724  230567      Spiritix  76561198173360875
#   52       724  231021     BELDIYA00  76561198376612283
#   53       724  231523      Spiritix  76561198173360875
#   54       724  232405      OzzieOzz  76561198066661071),
#  ('player_connect',
#             address    bot   name        networkid   tick user_name  \
#   0  www.faceit.com  False  ✩Maša  [U:1:398280526]  76643  MasaIDK_
#
#           user_steamid               xuid
#   0  76561198358546254  76561198358546254  ),
#  ('bomb_pickup',
#         tick
#   0     3120
#   1     3237
#   2     9134
#   3    15405
#   4    19042
#   ..     ...
#   76  229409
#   77  230576
#   78  231028
#   79  231569
#   80  232412
#
#   [81 rows x 1 columns]),
#  ('player_blind',
#       attacker_name   attacker_steamid  blind_duration  entityid    tick  \
#   0     3PARABELLUM  76561199074956403        0.621706       870   11226
#   1      godofbaldz  76561198259827471        0.101258      1015   12550
#   2      godofbaldz  76561198259827471        4.749978      1015   12550
#   3      godofbaldz  76561198259827471        1.995089       994   13281
#   4      godofbaldz  76561198259827471        0.987431       994   13281
#   ..            ...                ...             ...       ...     ...
#   240    godofbaldz  76561198259827471        4.076899       678  232546
#   241    godofbaldz  76561198259827471        0.915397       678  232546
#   242        fykseN  76561198014090099        0.261364       835  234207
#   243        fykseN  76561198014090099        1.779762       835  234207
#   244      Spiritix  76561198173360875        0.632613       562  234285
#
#           user_name       user_steamid
#   0     3PARABELLUM  76561199074956403
#   1       BELDIYA00  76561198376612283
#   2        OzzieOzz  76561198066661071
#   3      godofbaldz  76561198259827471
#   4       BELDIYA00  76561198376612283
#   ..            ...                ...
#   240    ADEODATUSS  76561199198706117
#   241  JustAnotherL  76561198264064168
#   242     BELDIYA00  76561198376612283
#   243      Spiritix  76561198173360875
#   244      Spiritix  76561198173360875
#
#   [245 rows x 7 columns]),
#  ('round_announce_final',
#        tick
#   0  176126
#   1  229409),
#  ('player_footstep',
#           tick   user_name       user_steamid
#   0       1415      fykseN  76561198014090099
#   1       1454      fykseN  76561198014090099
#   2       1558    OzzieOzz  76561198066661071
#   3       1575  godofbaldz  76561198259827471
#   4       1598    OzzieOzz  76561198066661071
#   ...      ...         ...                ...
#   1171  234512      fykseN  76561198014090099
#   1172  235014    Spiritix  76561198173360875
#   1173  235678   BELDIYA00  76561198376612283
#   1174  235684    OzzieOzz  76561198066661071
#   1175  235848    Spiritix  76561198173360875
#
#   [1176 rows x 3 columns]),
#  ('weapon_reload',
#          tick     user_name       user_steamid
#   0      6437      OzzieOzz  76561198066661071
#   1      6780    godofbaldz  76561198259827471
#   2      7163     BELDIYA00  76561198376612283
#   3      7473   3PARABELLUM  76561199074956403
#   4      7875   3PARABELLUM  76561199074956403
#   ..      ...           ...                ...
#   99   225869    ADEODATUSS  76561199198706117
#   100  227349    ADEODATUSS  76561199198706117
#   101  227472      OzzieOzz  76561198066661071
#   102  232014  JustAnotherL  76561198264064168
#   103  232277    ADEODATUSS  76561199198706117
#
#   [104 rows x 3 columns]),
#  ('player_hurt',
#        armor attacker_name   attacker_steamid  dmg_armor  dmg_health  health  \
#   0       97        fykseN  76561198014090099          3          34      66
#   1       97      OzzieOzz  76561198066661071          3          34      66
#   2       96     BELDIYA00  76561198376612283          4          55      45
#   3       93      Spiritix  76561198173360875          4          55      11
#   4       96   3PARABELLUM  76561199074956403          4          55      45
#   ..     ...           ...                ...        ...         ...     ...
#   833     80        fykseN  76561198014090099          4          13      37
#   834     82      OzzieOzz  76561198066661071         15         108       0
#   835     95   3PARABELLUM  76561199074956403          5          24      76
#   836     97     BELDIYA00  76561198376612283          3          27      73
#   837     97     BELDIYA00  76561198376612283          0         140       0
#
#        hitgroup    tick    user_name       user_steamid weapon
#   0           0    2262     OzzieOzz  76561198066661071  knife
#   1           0    2265       fykseN  76561198014090099  knife
#   2           0    2270  3PARABELLUM  76561199074956403  knife
#   3           0    2272       fykseN  76561198014090099  knife
#   4           0    2274    BELDIYA00  76561198376612283  knife
#   ..        ...     ...          ...                ...    ...
#   833         2  235219     OzzieOzz  76561198066661071    mp9
#   834         1  235227       fykseN  76561198014090099   ak47
#   835         2  236067    BELDIYA00  76561198376612283   m4a1
#   836         2  236069  3PARABELLUM  76561199074956403   ak47
#   837         1  236075  3PARABELLUM  76561199074956403   ak47
#
#   [838 rows x 11 columns]),
#  ('player_jump',
#           tick   user_name       user_steamid
#   0       1415      fykseN  76561198014090099
#   1       1454      fykseN  76561198014090099
#   2       1558    OzzieOzz  76561198066661071
#   3       1575  godofbaldz  76561198259827471
#   4       1598    OzzieOzz  76561198066661071
#   ...      ...         ...                ...
#   1259  235678   BELDIYA00  76561198376612283
#   1260  235684    OzzieOzz  76561198066661071
#   1261  235848    Spiritix  76561198173360875
#   1262  235910    Spiritix  76561198173360875
#   1263  235978    Spiritix  76561198173360875
#
#   [1264 rows x 3 columns]),
#  ('inferno_startburn',
#        entityid    tick     user_name       user_steamid            x  \
#   0         267    5478      Spiritix  76561198173360875   -43.526894
#   1         140   12666  JustAnotherL  76561198264064168  -788.684204
#   2         965   13365      MasaIDK_  76561198358546254  -948.305420
#   3         183   19649      Spiritix  76561198173360875 -1115.870239
#   4         932   19833      OzzieOzz  76561198066661071 -1527.844727
#   ..        ...     ...           ...                ...          ...
#   141       268  231358      OzzieOzz  76561198066661071  -462.968414
#   142       166  231565   3PARABELLUM  76561199074956403  1347.024536
#   143       374  232089    ADEODATUSS  76561199198706117 -1968.031372
#   144       900  232094      Spiritix  76561198173360875   154.389267
#   145       143  235562     -silentGG  76561198111191178  -923.850891
#
#                  y           z
#   0     602.061218    0.235298
#   1     375.895538  -39.000000
#   2    1130.854248   32.000000
#   3     840.478943   -1.968750
#   4     820.495178   38.031250
#   ..           ...         ...
#   141   366.713745  161.000000
#   142   887.684631 -149.968750
#   143   285.419189   73.000053
#   144   420.680054  -29.968750
#   145  1142.413574   32.000000
#
#   [146 rows x 7 columns]),
#  ('item_pickup',
#         defindex          item  silent    tick     user_name       user_steamid
#   0          507         knife   False       0          None               None
#   1           59         knife   False       0          None               None
#   2          522         knife   False       0          None               None
#   3          508         knife   False       0          None               None
#   4          522         knife   False       0          None               None
#   ...        ...           ...     ...     ...           ...                ...
#   2058        60          m4a1   False  231934  JustAnotherL  76561198264064168
#   2059        49            c4    True  232412     -silentGG  76561198111191178
#   2060        45  smokegrenade    True  232827  JustAnotherL  76561198264064168
#   2061        45  smokegrenade    True  233822    ADEODATUSS  76561199198706117
#   2062        43     flashbang    True  235837     -silentGG  76561198111191178
#
#   [2063 rows x 6 columns]),
#  ('flashbang_detonate',
#        entityid    tick    user_name       user_steamid            x  \
#   0         870   11226  3PARABELLUM  76561199074956403  -165.625931
#   1          73   11440  3PARABELLUM  76561199074956403  -229.742493
#   2        1015   12550   godofbaldz  76561198259827471  -765.864136
#   3         566   13126       fykseN  76561198014090099   934.854187
#   4         994   13281   godofbaldz  76561198259827471  -685.338745
#   ..        ...     ...          ...                ...          ...
#   179       601  231302       fykseN  76561198014090099   -78.332825
#   180        70  231363     Spiritix  76561198173360875   -43.387299
#   181       678  232546   godofbaldz  76561198259827471 -1424.478027
#   182       835  234207       fykseN  76561198014090099   -37.423489
#   183       562  234285     Spiritix  76561198173360875    83.764908
#
#                 y           z
#   0    409.725861    4.065005
#   1    476.950562   25.003874
#   2    224.882935  -76.094261
#   3    683.127197   98.083618
#   4    353.127625  -46.326866
#   ..          ...         ...
#   179   67.661011   45.055794
#   180  183.276550   15.321784
#   181  816.014160   52.104179
#   182  -12.246626  415.623901
#   183  513.078796   13.984215
#
#   [184 rows x 7 columns]),
#  ('round_announce_warmup',
#      tick
#   0  2676),
#  ('player_team',
#       disconnect  isbot  oldteam  silent  team    tick     user_name  \
#   0        False  False        3   False     2    3120     BELDIYA00
#   1        False  False        3   False     2    3120    godofbaldz
#   2        False  False        2   False     3    3120   3PARABELLUM
#   3        False  False        2   False     3    3120        fykseN
#   4        False  False        2   False     3    3120    ADEODATUSS
#   5        False  False        2   False     3    3120  JustAnotherL
#   6        False  False        3   False     2    3120     -silentGG
#   7        False  False        2   False     3    3120      MasaIDK_
#   8        False  False        3   False     2    3120      Spiritix
#   9        False  False        3   False     2    3120      OzzieOzz
#   10       False  False        2    True     3   85432      OzzieOzz
#   11       False  False        2    True     3   85432      Spiritix
#   12       False  False        3    True     2   85432      MasaIDK_
#   13       False  False        2    True     3   85432     -silentGG
#   14       False  False        3    True     2   85432  JustAnotherL
#   15       False  False        3    True     2   85432    ADEODATUSS
#   16       False  False        3    True     2   85432        fykseN
#   17       False  False        3    True     2   85432   3PARABELLUM
#   18       False  False        2    True     3   85432    godofbaldz
#   19       False  False        2    True     3   85432     BELDIYA00
#   20       False  False        3    True     2  211293      OzzieOzz
#   21       False  False        3    True     2  211293      Spiritix
#   22       False  False        2    True     3  211293      MasaIDK_
#   23       False  False        3    True     2  211293     -silentGG
#   24       False  False        2    True     3  211293  JustAnotherL
#   25       False  False        2    True     3  211293    ADEODATUSS
#   26       False  False        2    True     3  211293        fykseN
#   27       False  False        2    True     3  211293   3PARABELLUM
#   28       False  False        3    True     2  211293    godofbaldz
#   29       False  False        3    True     2  211293     BELDIYA00
#
#            user_steamid
#   0   76561198376612283
#   1   76561198259827471
#   2   76561199074956403
#   3   76561198014090099
#   4   76561199198706117
#   5   76561198264064168
#   6   76561198111191178
#   7   76561198358546254
#   8   76561198173360875
#   9   76561198066661071
#   10  76561198066661071
#   11  76561198173360875
#   12  76561198358546254
#   13  76561198111191178
#   14  76561198264064168
#   15  76561199198706117
#   16  76561198014090099
#   17  76561199074956403
#   18  76561198259827471
#   19  76561198376612283
#   20  76561198066661071
#   21  76561198173360875
#   22  76561198358546254
#   23  76561198111191178
#   24  76561198264064168
#   25  76561199198706117
#   26  76561198014090099
#   27  76561199074956403
#   28  76561198259827471
#   29  76561198376612283  ),
#  ('round_freeze_end',
#         tick
#   0     1279
#   1     2803
#   2     4933
#   3    10414
#   4    18605
#   5    23020
#   6    27893
#   7    33918
#   8    42352
#   9    49137
#   10   58972
#   11   64869
#   12   69416
#   13   78344
#   14   87128
#   15   91973
#   16   99864
#   17  108801
#   18  114538
#   19  123772
#   20  132108
#   21  140254
#   22  147855
#   23  158095
#   24  169258
#   25  180332
#   26  186975
#   27  195329
#   28  203705
#   29  212989
#   30  221565
#   31  230689),
#  ('server_cvar',
#                              name  tick          value
#   0                    sv_minrate    -1         128000
#   1                   think_limit    -1              0
#   2               mp_friendlyfire    -1           true
#   3                  sv_specspeed    -1              3
#   4                mp_forcecamera    -1              1
#   ..                          ...   ...            ...
#   90        mp_death_drop_defuser  3119           true
#   91        mp_death_drop_grenade  3119              2
#   92            mp_death_drop_gun  3119              1
#   93  steamworks_sessionid_server  3243              0
#   94  steamworks_sessionid_server  3263  8787844527122
#
#   [95 rows x 3 columns]),
#  ('smokegrenade_detonate',
#        entityid    tick     user_name       user_steamid            x  \
#   0         103    5518      OzzieOzz  76561198066661071 -1223.183716
#   1         131   10885      MasaIDK_  76561198358546254   -99.676834
#   2         482   10997      OzzieOzz  76561198066661071  -482.176483
#   3         445   11410   3PARABELLUM  76561199074956403   -96.881828
#   4         161   11841        fykseN  76561198014090099  1110.971558
#   ..        ...     ...           ...                ...          ...
#   184       907  232556  JustAnotherL  76561198264064168 -1601.191772
#   185       199  234244    ADEODATUSS  76561199198706117  -720.283142
#   186       788  234718    godofbaldz  76561198259827471  -654.028992
#   187       403  234937     -silentGG  76561198111191178 -1180.685181
#   188       226  235617      OzzieOzz  76561198066661071  -388.965118
#
#                  y           z
#   0     798.507202    2.031250
#   1     909.097961   49.871250
#   2      60.845169 -117.968750
#   3     152.567871    2.170787
#   4     639.946228 -186.833633
#   ..           ...         ...
#   184   425.613953    2.031250
#   185   672.724792   38.031250
#   186  1149.381348   34.031250
#   187  1175.646118   -5.800238
#   188   115.375023 -117.968750
#
#   [189 rows x 7 columns]),
#  ('bomb_defused',
#      site    tick    user_name       user_steamid
#   0   348    8686  3PARABELLUM  76561199074956403
#   1   236  175678   godofbaldz  76561198259827471),
#  ('bomb_exploded',
#      site    tick     user_name       user_steamid
#   0   236   40624      OzzieOzz  76561198066661071
#   1   348   57244     -silentGG  76561198111191178
#   2   348  122044      MasaIDK_  76561198358546254
#   3   348  156367  JustAnotherL  76561198264064168
#   4   348  238008          None               None),
#  ('round_announce_last_round_half',
#        tick
#   0   77064
#   1  202425),
#  ('player_disconnect',
#       PlayerID          name         networkid  reason    tick     user_name  \
#   0          0      MasaIDK_   [U:1:398280526]       2   73972      MasaIDK_
#   1          0        fykseN    [U:1:53824371]       2  236227        fykseN
#   2          0    ADEODATUSS  [U:1:1238440389]       2  236304    ADEODATUSS
#   3          0   3PARABELLUM  [U:1:1114690675]      59  236353   3PARABELLUM
#   4          0     -silentGG   [U:1:150925450]       2  236409     -silentGG
#   5          0     BELDIYA00   [U:1:416346555]       2  236409     BELDIYA00
#   6          0      MasaIDK_   [U:1:398280526]       2  236605      MasaIDK_
#   7          0    godofbaldz   [U:1:299561743]       2  236724    godofbaldz
#   8          0      OzzieOzz   [U:1:106395343]       3  237058      OzzieOzz
#   9          0      Spiritix   [U:1:213095147]       3  237058      Spiritix
#   10         0  JustAnotherL   [U:1:303798440]       3  237058  JustAnotherL
#
#            user_steamid               xuid
#   0   76561198358546254  76561198358546254
#   1   76561198014090099  76561198014090099
#   2   76561199198706117  76561199198706117
#   3   76561199074956403  76561199074956403
#   4   76561198111191178  76561198111191178
#   5   76561198376612283  76561198376612283
#   6   76561198358546254  76561198358546254
#   7   76561198259827471  76561198259827471
#   8   76561198066661071  76561198066661071
#   9   76561198173360875  76561198173360875
#   10  76561198264064168  76561198264064168  ),
#  ('item_equip',
#          canzoom  defindex  hassilencer  hastracers  ispainted  issilenced  \
#   0        False         0        False       False       True       False
#   1        False         0        False       False      False       False
#   2        False         0        False       False       True       False
#   3        False         0        False       False       True       False
#   4        False         0        False       False       True       False
#   ...        ...       ...          ...         ...        ...         ...
#   12253    False         0        False        True       True       False
#   12254    False         0        False       False       True       False
#   12255    False         0        False       False       True       False
#   12256    False         0        False       False       True       False
#   12257    False         0        False        True      False       False
#
#           item    tick   user_name       user_steamid  weptype
#   0      knife       0        None               None        0
#   1      knife       0        None               None        0
#   2      knife       0        None               None        0
#   3      knife       0        None               None        0
#   4      knife       0        None               None        0
#   ...      ...     ...         ...                ...      ...
#   12253  glock  236136    Spiritix  76561198173360875        1
#   12254  knife  236137    OzzieOzz  76561198066661071        0
#   12255  knife  236139  godofbaldz  76561198259827471        0
#   12256  knife  236147    Spiritix  76561198173360875        0
#   12257  glock  236409   BELDIYA00  76561198376612283        1
#
#   [12258 rows x 11 columns]),
#  ('round_announce_match_start',
#      tick
#   0  1279
#   1  4933),
#  ('round_officially_ended',
#         tick
#   0     9134
#   1     9134
#   2    15405
#   3    15405
#   4    21740
#   5    21740
#   6    26613
#   7    26613
#   8    32638
#   9    32638
#   10   41072
#   11   41072
#   12   47857
#   13   47857
#   14   57692
#   15   57692
#   16   63589
#   17   63589
#   18   68136
#   19   68136
#   20   77064
#   21   77064
#   22   85432
#   23   85432
#   24   90693
#   25   90693
#   26   98584
#   27   98584
#   28  107521
#   29  107521
#   30  113258
#   31  113258
#   32  122492
#   33  122492
#   34  130828
#   35  130828
#   36  138974
#   37  138974
#   38  146575
#   39  146575
#   40  156815
#   41  156815
#   42  164983
#   43  164983
#   44  176126
#   45  176126
#   46  185279
#   47  185279
#   48  194049
#   49  194049
#   50  202425
#   51  202425
#   52  211293
#   53  211293
#   54  220285
#   55  220285
#   56  229409
#   57  229409),
#  ('player_connect_full',
#       tick user_name       user_steamid
#   0  77046  MasaIDK_  76561198358546254),
#  ('weapon_zoom',
#          tick   user_name       user_steamid
#   0     34698  godofbaldz  76561198259827471
#   1     35221  godofbaldz  76561198259827471
#   2     37808  godofbaldz  76561198259827471
#   3     37840  godofbaldz  76561198259827471
#   4     37859  godofbaldz  76561198259827471
#   ..      ...         ...                ...
#   186  232568  godofbaldz  76561198259827471
#   187  234603  godofbaldz  76561198259827471
#   188  234738  godofbaldz  76561198259827471
#   189  234757  godofbaldz  76561198259827471
#   190  234942  godofbaldz  76561198259827471
#
#   [191 rows x 3 columns]),
#  ('player_death',
#        assistedflash assister_name   assister_steamid attacker_name  \
#   0            False      Spiritix  76561198173360875      OzzieOzz
#   1            False  JustAnotherL  76561198264064168    ADEODATUSS
#   2            False     BELDIYA00  76561198376612283    godofbaldz
#   3            False   3PARABELLUM  76561199074956403    ADEODATUSS
#   4            False      MasaIDK_  76561198358546254  JustAnotherL
#   ..             ...           ...                ...           ...
#   204          False          None               None    godofbaldz
#   205          False          None               None    godofbaldz
#   206          False          None               None    godofbaldz
#   207          False          None               None      OzzieOzz
#   208          False          None               None     BELDIYA00
#
#         attacker_steamid  attackerblind   distance  dmg_armor  dmg_health  \
#   0    76561198066661071          False   1.265543          1          21
#   1    76561199198706117          False   0.898216          4          56
#   2    76561198259827471          False   1.060491          4          56
#   3    76561199198706117          False   1.178760          4          55
#   4    76561198264064168          False   1.526532          4          56
#   ..                 ...            ...        ...        ...         ...
#   204  76561198259827471          False  29.865206          1         110
#   205  76561198259827471          False  33.921307          1         136
#   206  76561198259827471          False  27.526186          1         137
#   207  76561198066661071          False  20.211832         15         108
#   208  76561198376612283          False  18.837309          0         140
#
#        dominated  ...  revenge  thrusmoke    tick     user_name  \
#   0            0  ...        0      False    2297        fykseN
#   1            0  ...        0      False    2320     -silentGG
#   2            0  ...        0      False    2355   3PARABELLUM
#   3            0  ...        0      False    2391     BELDIYA00
#   4            0  ...        0      False    2396      Spiritix
#   ..         ...  ...      ...        ...     ...           ...
#   204          0  ...        0      False  231588      MasaIDK_
#   205          0  ...        0      False  234140    ADEODATUSS
#   206          0  ...        0      False  234390  JustAnotherL
#   207          0  ...        0      False  235227        fykseN
#   208          0  ...        0      False  236075   3PARABELLUM
#
#             user_steamid           weapon     weapon_fauxitemid  weapon_itemid  \
#   0    76561198014090099  knife_butterfly  17293822569105523203    35477304051
#   1    76561198111191178          knife_t  17293822569102704699              0
#   2    76561199074956403   knife_skeleton  17293822569103491597    35167355779
#   3    76561198376612283          knife_t  17293822569102704699              0
#   4    76561198173360875   knife_stiletto  17293822569106571786    34873144654
#   ..                 ...              ...                   ...            ...
#   204  76561198358546254              awp  17293822569116598281    33914766179
#   205  76561199198706117              awp  17293822569116598281    33914766179
#   206  76561198264064168              awp  17293822569116598281    33914766179
#   207  76561198014090099             ak47  17293822569133768711    35297643185
#   208  76561199074956403             ak47  17293822569102704647    35774257056
#
#       weapon_originalowner_xuid wipe
#   0                                0
#   1                                0
#   2                                0
#   3                                0
#   4                                0
#   ..                        ...  ...
#   204                              0
#   205                              0
#   206                              0
#   207                              0
#   208                              0
#
#   [209 rows x 25 columns]),
#  ('player_spawn',
#          tick    user_name       user_steamid
#   0         0         None               None
#   1         0         None               None
#   2         0         None               None
#   3         0         None               None
#   4         0         None               None
#   ..      ...          ...                ...
#   327  229409   ADEODATUSS  76561199198706117
#   328  229409  3PARABELLUM  76561199074956403
#   329  229409   godofbaldz  76561198259827471
#   330  229409     OzzieOzz  76561198066661071
#   331  229409    -silentGG  76561198111191178
#
#   [332 rows x 3 columns]),
#  ('cs_round_start_beep',
#         tick
#   0     1088
#   1     1152
#   2     1216
#   3     2676
#   4     2740
#   ..     ...
#   90  221438
#   91  221502
#   92  230498
#   93  230562
#   94  230626
#
#   [95 rows x 1 columns]),
#  ('cs_round_final_beep',
#         tick
#   0     1279
#   1     2803
#   2     4933
#   3    10414
#   4    18605
#   5    23020
#   6    27893
#   7    33918
#   8    42352
#   9    49137
#   10   58972
#   11   64869
#   12   69416
#   13   78344
#   14   87128
#   15   91973
#   16   99864
#   17  108801
#   18  114538
#   19  123772
#   20  132108
#   21  140254
#   22  147855
#   23  158095
#   24  169258
#   25  180332
#   26  186975
#   27  195329
#   28  203705
#   29  212989
#   30  221565
#   31  230689),
#  ('bomb_beginplant',
#       site    tick     user_name       user_steamid
#   0    348    6621      OzzieOzz  76561198066661071
#   1    348   13475      OzzieOzz  76561198066661071
#   2    348   21398    godofbaldz  76561198259827471
#   3    236   25121      OzzieOzz  76561198066661071
#   4    236   37800      OzzieOzz  76561198066661071
#   5    348   46096      Spiritix  76561198173360875
#   6    348   54420     -silentGG  76561198111191178
#   7    348   61248    godofbaldz  76561198259827471
#   8    236   67879     -silentGG  76561198111191178
#   9    236   76174     BELDIYA00  76561198376612283
#   10   236   84513     -silentGG  76561198111191178
#   11   348   88912  JustAnotherL  76561198264064168
#   12   236   96878    ADEODATUSS  76561199198706117
#   13   348  106758    ADEODATUSS  76561199198706117
#   14   348  113056  JustAnotherL  76561198264064168
#   15   348  119220      MasaIDK_  76561198358546254
#   16   236  129101        fykseN  76561198014090099
#   17   348  136551      MasaIDK_  76561198358546254
#   18   348  153543  JustAnotherL  76561198264064168
#   19   236  174117  JustAnotherL  76561198264064168
#   20   236  183612    ADEODATUSS  76561199198706117
#   21   348  200412        fykseN  76561198014090099
#   22   348  208710   3PARABELLUM  76561199074956403
#   23   348  219241    godofbaldz  76561198259827471
#   24   348  227272     BELDIYA00  76561198376612283
#   25   348  227454     BELDIYA00  76561198376612283
#   26   348  235184     -silentGG  76561198111191178),
#  ('bomb_begindefuse',
#      haskit    tick    user_name       user_steamid
#   0   False    8046  3PARABELLUM  76561199074956403
#   1    True  175358   godofbaldz  76561198259827471),
#  ('begin_new_match',
#      tick
#   0     0
#   1  3243),
#  ('weapon_fire',
#         silenced    tick    user_name       user_steamid  \
#   0        False    1780    -silentGG  76561198111191178
#   1        False    2262       fykseN  76561198014090099
#   2        False    2265     OzzieOzz  76561198066661071
#   3        False    2294       fykseN  76561198014090099
#   4        False    2297     OzzieOzz  76561198066661071
#   ...        ...     ...          ...                ...
#   4416     False  236068    -silentGG  76561198111191178
#   4417     False  236069    BELDIYA00  76561198376612283
#   4418      True  236073  3PARABELLUM  76561199074956403
#   4419     False  236074    -silentGG  76561198111191178
#   4420     False  236075    BELDIYA00  76561198376612283
#
#                          weapon
#   0     weapon_knife_m9_bayonet
#   1       weapon_knife_karambit
#   2      weapon_knife_butterfly
#   3       weapon_knife_karambit
#   4      weapon_knife_butterfly
#   ...                       ...
#   4416              weapon_ak47
#   4417              weapon_ak47
#   4418     weapon_m4a1_silencer
#   4419              weapon_ak47
#   4420              weapon_ak47
#
#   [4421 rows x 5 columns]),
#  ('round_poststart',
#         tick
#   0        0
#   1     2676
#   2     3120
#   3     3237
#   4     9134
#   5    15405
#   6    21740
#   7    26613
#   8    32638
#   9    41072
#   10   47857
#   11   57692
#   12   63589
#   13   68136
#   14   77064
#   15   85432
#   16   90693
#   17   98584
#   18  107521
#   19  113258
#   20  122492
#   21  130828
#   22  138974
#   23  146575
#   24  156815
#   25  164983
#   26  176126
#   27  185279
#   28  194049
#   29  202425
#   30  211293
#   31  220285
#   32  229409),
#  ('hltv_chase',
#        distance  inertia  ineye  phi  target1  target2  theta    tick
#   0         112        0      0   20       10    65535    -20      86
#   1         112        0      0   20        8    65535     20     406
#   2         112        0      0   20        7        8     20    1046
#   3         112        0      0   20       12        6    -20    1366
#   4         112        0      0   20        4        3     20    1686
#   ..        ...      ...    ...  ...      ...      ...    ...     ...
#   516        96        0      1  -20        3        9    -30  234837
#   517        96        0      1  -20        9        3     30  235221
#   518        96        0      1  -20       12       10    -30  235738
#   519       112        0      0   20       12    65535    -20  236122
#   520       112        0      0   20        3    65535     20  236762
#
#   [521 rows x 8 columns]),
#  ('hltv_fixed',
#               fov  offset  phi  posx  posy  posz  target  theta    tick
#   0     93.256607       0   66  -625  1935   202      11     24     726
#   1     61.289417       0   66  -625  1935   202       4     24    2518
#   2     66.152832       0   66  -625  1935   202       5     24    2902
#   3     64.194008       0   66  -625  1935   202       5     24    4566
#   4     67.067734       0   59 -1354   366    48      10    -21    8558
#   ..          ...     ...  ...   ...   ...   ...     ...    ...     ...
#   135   52.871113       0   66  -625  1935   202   65535     24  243546
#   136   95.930855       0  256  1431  2268    11   65535     10  243866
#   137   88.274437       0   66  -625  1935   202   65535     24  244186
#   138   53.702698       0  256  1431  2268    11   65535     10  244506
#   139  103.856522       0   66  -625  1935   202   65535     24  244803
#
#   [140 rows x 9 columns]),
#  ('round_end',
#              reason  round    tick winner
#   0       ct_killed      2    2498      T
#   1    bomb_defused      3    8686     CT
#   2       ct_killed      4   14957      T
#   3       ct_killed      5   21292      T
#   4       ct_killed      6   26165      T
#   5        t_killed      7   32190     CT
#   6   bomb_exploded      8   40624      T
#   7        t_killed      9   47409     CT
#   8   bomb_exploded     10   57244      T
#   9       ct_killed     11   63141      T
#   10      ct_killed     12   67688      T
#   11      ct_killed     13   76616      T
#   12      ct_killed     14   84888      T
#   13      ct_killed     15   90245      T
#   14      ct_killed     16   98136      T
#   15      ct_killed     17  107073      T
#   16      ct_killed     18  112810      T
#   17  bomb_exploded     19  122044      T
#   18      ct_killed     20  130380      T
#   19      ct_killed     21  138526      T
#   20       t_killed     22  146127     CT
#   21  bomb_exploded     23  156367      T
#   22       t_killed     24  164535     CT
#   23   bomb_defused     25  175678     CT
#   24      ct_killed     26  184735      T
#   25       t_killed     27  193601     CT
#   26      ct_killed     28  201977      T
#   27      ct_killed     29  210749      T
#   28      ct_killed     30  219837      T
#   29      ct_killed     31  228961      T
#   30      ct_killed     32  236075      T),
#  ('decoy_started',
#      entityid    tick   user_name       user_steamid            x           y  \
#   0       995    7173   BELDIYA00  76561198376612283  -290.110016  289.303162
#   1       470  182610  ADEODATUSS  76561199198706117  1564.474487  783.890808
#
#               z
#   0 -133.946091
#   1 -143.968750  ),
#  ('decoy_detonate',
#      entityid    tick   user_name       user_steamid            x           y  \
#   0       995    8222   BELDIYA00  76561198376612283  -290.110016  289.303162
#   1       470  183577  ADEODATUSS  76561199198706117  1564.474487  783.890808
#
#               z
#   0 -133.946091
#   1 -143.968750  ),
#  ('smokegrenade_expired',
#        entityid    tick     user_name       user_steamid            x  \
#   0         103    6930      OzzieOzz  76561198066661071 -1223.183716
#   1         131   12297      MasaIDK_  76561198358546254   -99.676834
#   2         482   12409      OzzieOzz  76561198066661071  -482.176483
#   3         445   12822   3PARABELLUM  76561199074956403   -96.881828
#   4         161   13253        fykseN  76561198014090099  1110.971558
#   ..        ...     ...           ...                ...          ...
#   180       907  233968  JustAnotherL  76561198264064168 -1601.191772
#   181       199  235656    ADEODATUSS  76561199198706117  -720.283142
#   182       788  236130    godofbaldz  76561198259827471  -654.028992
#   183       403  236349     -silentGG  76561198111191178 -1180.685181
#   184       226  237029      OzzieOzz  76561198066661071  -388.965118
#
#                  y           z
#   0     798.507202    2.031250
#   1     909.097961   49.871250
#   2      60.845169 -117.968750
#   3     152.567871    2.170787
#   4     639.946228 -186.833633
#   ..           ...         ...
#   180   425.613953    2.031250
#   181   672.724792   38.031250
#   182  1149.381348   34.031250
#   183  1175.646118   -5.800238
#   184   115.375023 -117.968750
#
#   [185 rows x 7 columns]),
#  ('other_death',
#      attacker_name   attacker_steamid  attackerblind  headshot  noscope  \
#   0       OzzieOzz  76561198066661071          False     False    False
#   1       MasaIDK_  76561198358546254          False     False    False
#   2       MasaIDK_  76561198358546254          False     False    False
#   3       Spiritix  76561198173360875          False     False    False
#   4       Spiritix  76561198173360875          False     False    False
#   ..           ...                ...            ...       ...      ...
#   56    ADEODATUSS  76561199198706117          False     False    False
#   57      OzzieOzz  76561198066661071          False     False    False
#   58      OzzieOzz  76561198066661071          False     False    False
#   59     -silentGG  76561198111191178          False     False    False
#   60     -silentGG  76561198111191178          False     False    False
#
#       otherid     othertype  penetrated  thrusmoke    tick         weapon  \
#   0       784  prop_dynamic           0      False    7116          glock
#   1       821  prop_dynamic           0      False   13392        inferno
#   2       990  prop_dynamic           0      False   13405        inferno
#   3       286  prop_dynamic           1      False   19680  m4a1_silencer
#   4       151  prop_dynamic           0      False   19996      hegrenade
#   ..      ...           ...         ...        ...     ...            ...
#   56      867  prop_dynamic           0      False  225858      hegrenade
#   57      106  prop_dynamic           0      False  227176        inferno
#   58      483  prop_dynamic           0      False  227176        inferno
#   59      420  prop_dynamic           0      False  235589        inferno
#   60      529  prop_dynamic           0      False  235589        inferno
#
#          weapon_fauxitemid weapon_itemid weapon_originalowner_xuid
#   0   17293822569142484996    9625445227
#   1
#   2
#   3   17293822569102704700             0
#   4
#   ..                   ...           ...                       ...
#   56
#   57
#   58
#   59
#   60
#
#   [61 rows x 14 columns]),
#  ('show_survival_respawn_status',
#        duration                                          loc_token    tick  \
#   0           5  <img src="https://distribution.faceit-cdn.net/...  229411
#   1           5  <img src="https://distribution.faceit-cdn.net/...  229413
#   2           5  <img src="https://distribution.faceit-cdn.net/...  229415
#   3           5  <img src="https://distribution.faceit-cdn.net/...  229417
#   4           5  <img src="https://distribution.faceit-cdn.net/...  229419
#   ..        ...                                                ...     ...
#   154         5  <img src="https://distribution.faceit-cdn.net/...  229720
#   155         5  <img src="https://distribution.faceit-cdn.net/...  229722
#   156         5  <img src="https://distribution.faceit-cdn.net/...  229724
#   157         5  <img src="https://distribution.faceit-cdn.net/...  229726
#   158         5  <img src="https://distribution.faceit-cdn.net/...  229728
#
#        user_name  user_steamid
#   0          NaN           NaN
#   1          NaN           NaN
#   2          NaN           NaN
#   3          NaN           NaN
#   4          NaN           NaN
#   ..         ...           ...
#   154        NaN           NaN
#   155        NaN           NaN
#   156        NaN           NaN
#   157        NaN           NaN
#   158        NaN           NaN
#
#   [159 rows x 5 columns]),
#  ('inferno_expire',
#        entityid    tick     user_name       user_steamid            x  \
#   0         267    5928      Spiritix  76561198173360875   -43.526894
#   1         140   13115  JustAnotherL  76561198264064168  -788.684204
#   2         965   13578      MasaIDK_  76561198358546254  -948.305420
#   3         183   20098      Spiritix  76561198173360875 -1115.870239
#   4         932   20282      OzzieOzz  76561198066661071 -1527.844727
#   ..        ...     ...           ...                ...          ...
#   141       268  231807      OzzieOzz  76561198066661071  -462.968414
#   142       166  231880   3PARABELLUM  76561199074956403  1347.024536
#   143       374  232538    ADEODATUSS  76561199198706117 -1968.031372
#   144       900  232543      Spiritix  76561198173360875   154.389267
#   145       143  236011     -silentGG  76561198111191178  -923.850891
#
#                  y           z
#   0     602.061218    0.235298
#   1     375.895538  -39.000000
#   2    1130.854248   32.000000
#   3     840.478943   -1.968750
#   4     820.495178   38.031250
#   ..           ...         ...
#   141   366.713745  161.000000
#   142   887.684631 -149.968750
#   143   285.419189   73.000053
#   144   420.680054  -29.968750
#   145  1142.413574   32.000000
#
#   [146 rows x 7 columns]),
#  ('bomb_planted',
#       site    tick     user_name       user_steamid
#   0    348    6821      OzzieOzz  76561198066661071
#   1    348   13675      OzzieOzz  76561198066661071
#   2    348   21598    godofbaldz  76561198259827471
#   3    236   25321      OzzieOzz  76561198066661071
#   4    236   38000      OzzieOzz  76561198066661071
#   5    348   54620     -silentGG  76561198111191178
#   6    348   61448    godofbaldz  76561198259827471
#   7    236   68079     -silentGG  76561198111191178
#   8    236   76374     BELDIYA00  76561198376612283
#   9    236   84713     -silentGG  76561198111191178
#   10   348   89112  JustAnotherL  76561198264064168
#   11   236   97078    ADEODATUSS  76561199198706117
#   12   348  106958    ADEODATUSS  76561199198706117
#   13   348  113256  JustAnotherL  76561198264064168
#   14   348  119420      MasaIDK_  76561198358546254
#   15   236  129301        fykseN  76561198014090099
#   16   348  136751      MasaIDK_  76561198358546254
#   17   348  153743  JustAnotherL  76561198264064168
#   18   236  174317  JustAnotherL  76561198264064168
#   19   236  183812    ADEODATUSS  76561199198706117
#   20   348  200612        fykseN  76561198014090099
#   21   348  208910   3PARABELLUM  76561199074956403
#   22   348  219441    godofbaldz  76561198259827471
#   23   348  227654     BELDIYA00  76561198376612283
#   24   348  235384     -silentGG  76561198111191178),
#  ('announce_phase_end',
#        tick
#   0   85081
#   1  184928
#   2  210942),
#  ('cs_win_panel_match',
#        tick
#   0  236268),
#  ('cs_pre_restart',
#         tick
#   0     3218
#   1     9115
#   2    15386
#   3    21721
#   4    26594
#   5    32619
#   6    41053
#   7    47838
#   8    57673
#   9    63569
#   10   68117
#   11   77045
#   12   85413
#   13   90673
#   14   98565
#   15  107502
#   16  113239
#   17  122473
#   18  130809
#   19  138955
#   20  146556
#   21  156796
#   22  164964
#   23  176107
#   24  185260
#   25  194030
#   26  202406
#   27  211274
#   28  220266
#   29  229390),
#  ('round_start',
#       round    tick
#   0       1       0
#   1       1    2676
#   2       1    3120
#   3       1    3237
#   4       2    9134
#   5       3   15405
#   6       4   21740
#   7       5   26613
#   8       6   32638
#   9       7   41072
#   10      8   47857
#   11      9   57692
#   12     10   63589
#   13     11   68136
#   14     12   77064
#   15     13   85432
#   16     14   90693
#   17     15   98584
#   18     16  107521
#   19     17  113258
#   20     18  122492
#   21     19  130828
#   22     20  138974
#   23     21  146575
#   24     22  156815
#   25     23  164983
#   26     24  176126
#   27     25  185279
#   28     26  194049
#   29     27  202425
#   30     28  211293
#   31     29  220285
#   32     30  229409),
#  ('round_time_warning',
#         tick
#   0    40639
#   1    55858
#   2    76137
#   3    85065
#   4   106585
#   5   121259
#   6   130493
#   7   138829
#   8   154576
#   9   164816
#   10  175979
#   11  193696
#   12  202050
#   13  210426
#   14  219710
#   15  228286),
#  ('hegrenade_detonate',
#        entityid    tick    user_name       user_steamid            x  \
#   0         422   11044     MasaIDK_  76561198358546254  -228.340454
#   1         807   11090       fykseN  76561198014090099   758.970520
#   2        1006   11104  3PARABELLUM  76561199074956403  -145.077286
#   3         641   19330   godofbaldz  76561198259827471  -102.799759
#   4         199   19996     Spiritix  76561198173360875 -1062.057129
#   ..        ...     ...          ...                ...          ...
#   134       504  225858   ADEODATUSS  76561199198706117   149.968674
#   135       101  231785     Spiritix  76561198173360875   -81.887352
#   136       903  232081  3PARABELLUM  76561199074956403   874.656677
#   137       612  232401   godofbaldz  76561198259827471 -1356.468506
#   138        97  233119     OzzieOzz  76561198066661071  -873.962830
#
#                  y           z
#   0    -416.872345   22.637392
#   1     101.011810  -42.600368
#   2      94.376869   13.753197
#   3     191.545059   10.544771
#   4     937.891602   41.096153
#   ..           ...         ...
#   134  1234.449341  -29.797083
#   135     9.524642    2.247569
#   136   788.663757 -184.939575
#   137   734.670959   13.161931
#   138   526.982849   72.000702
#
#   [139 rows x 7 columns])]

# %% [markdown]
# #### Initialisation du DF Rounds et Ticks

# %%
rounds_ticks = demo1.parse_event('round_start')

# %%
rounds_ticks
# Out:
#     round    tick
# 0       1       0
# 1       1    2676
# 2       1    3120
# 3       1    3237
# 4       2    9134
# 5       3   15405
# 6       4   21740
# 7       5   26613
# 8       6   32638
# 9       7   41072
# 10      8   47857
# 11      9   57692
# 12     10   63589
# 13     11   68136
# 14     12   77064
# 15     13   85432
# 16     14   90693
# 17     15   98584
# 18     16  107521
# 19     17  113258
# 20     18  122492
# 21     19  130828
# 22     20  138974
# 23     21  146575
# 24     22  156815
# 25     23  164983
# 26     24  176126
# 27     25  185279
# 28     26  194049
# 29     27  202425
# 30     28  211293
# 31     29  220285
# 32     30  229409

# %% [markdown]
# Isolation des ticks de début de rounds effectifs, sur faceit :
# - R1 = Knife round -> freezetime
# - R2 = Warmup -> freezetime
# - R3 = RR -> pas de freezetime
# - R4 = 1er round
#
# On supprime donc le tick 0 (knife) + le tick 2676 (warmup) + le tick  3120 (RR) pour ne démarrer qu'a partir du tick 3237 qui correspond au vrai premier round IG

# %%
rounds_ticks = rounds_ticks.drop([0,1,2])

# %%
first_round_tick = rounds_ticks.loc[3, 'tick']
first_round_tick
# Out:
# 3237

# %% [markdown]
# #### Freezetime end

# %%
freezetime_end_tick = demo1.parse_event("round_freeze_end")["tick"].drop([0,1]).tolist()

# %%
freezetime_end_tick
# Out:
# [4933,
#  10414,
#  18605,
#  23020,
#  27893,
#  33918,
#  42352,
#  49137,
#  58972,
#  64869,
#  69416,
#  78344,
#  87128,
#  91973,
#  99864,
#  108801,
#  114538,
#  123772,
#  132108,
#  140254,
#  147855,
#  158095,
#  169258,
#  180332,
#  186975,
#  195329,
#  203705,
#  212989,
#  221565,
#  230689]

# %% [markdown]
# #### Map

# %%
map = pd.DataFrame([demo1.parse_header()])
map
# Out:
#     map_name               game_directory demo_file_stamp demo_version_name  \
# 0  de_anubis  /home/hz00604/cs2/game/csgo        PBDEMS2      valve_demo_2
#
#   network_protocol allow_clientside_entities  \
# 0            13994                      true
#
#                       demo_version_guid addons    client_name  \
# 0  8e9d71ab-04a1-4c01-bb61-acfede27c046         SourceTV Demo
#
#                         server_name fullpackets_version  \
# 0  FACEIT.com register to play here                   2
#
#   allow_clientside_particles
# 0                       true

# %%
map2 = pd.DataFrame([demo2.parse_header()])
map2
# Out:
#                 game_directory                       server_name  \
# 0  /home/hz01872/cs2/game/csgo  FACEIT.com register to play here
#
#      client_name addons    map_name network_protocol fullpackets_version  \
# 0  SourceTV Demo         de_vertigo            13985                   2
#
#                       demo_version_guid allow_clientside_particles  \
# 0  8e9d71ab-04a1-4c01-bb61-acfede27c046                       true
#
#   allow_clientside_entities demo_file_stamp demo_version_name
# 0                      true        PBDEMS2      valve_demo_2

# %% [markdown]
# #### Bomb plant

# %%
bombsite = demo1.parse_event("bomb_planted", player=["last_place_name"])
bombsite
# Out:
#     site    tick user_last_place_name     user_name       user_steamid
# 0    348    6821            BombsiteB      OzzieOzz  76561198066661071
# 1    348   13675            BombsiteB      OzzieOzz  76561198066661071
# 2    348   21598            BombsiteB    godofbaldz  76561198259827471
# 3    236   25321            BombsiteA      OzzieOzz  76561198066661071
# 4    236   38000            BombsiteA      OzzieOzz  76561198066661071
# 5    348   54620            BombsiteB     -silentGG  76561198111191178
# 6    348   61448            BombsiteB    godofbaldz  76561198259827471
# 7    236   68079            BombsiteA     -silentGG  76561198111191178
# 8    236   76374            BombsiteA     BELDIYA00  76561198376612283
# 9    236   84713            BombsiteA     -silentGG  76561198111191178
# 10   348   89112            BombsiteB  JustAnotherL  76561198264064168
# 11   236   97078            BombsiteA    ADEODATUSS  76561199198706117
# 12   348  106958            BombsiteB    ADEODATUSS  76561199198706117
# 13   348  113256            BombsiteB  JustAnotherL  76561198264064168
# 14   348  119420            BombsiteB      MasaIDK_  76561198358546254
# 15   236  129301            BombsiteA        fykseN  76561198014090099
# 16   348  136751            BombsiteB      MasaIDK_  76561198358546254
# 17   348  153743            BombsiteB  JustAnotherL  76561198264064168
# 18   236  174317            BombsiteA  JustAnotherL  76561198264064168
# 19   236  183812            BombsiteA    ADEODATUSS  76561199198706117
# 20   348  200612            BombsiteB        fykseN  76561198014090099
# 21   348  208910            BombsiteB   3PARABELLUM  76561199074956403
# 22   348  219441            BombsiteB    godofbaldz  76561198259827471
# 23   348  227654            BombsiteB     BELDIYA00  76561198376612283
# 24   348  235384            BombsiteB     -silentGG  76561198111191178

# %% [markdown]
# ## Tables intermédiaires

# %% [markdown]
# #### Equipe et side

# %%
zobrux = ['OzzieOzz','-silentGG','godofbaldz','BELDIYA00','Spiritix']
Equipe = 'zobrux'

# %% [markdown]
# Une valeur de Team pour chaque joueur est ajoutée pour chaque changement de side, dans le cas de notre game témoin :
# - tick 3120 : Changement de side suite au Knife round (puis la game est RR donc vrai début de la partie au ticke 3237 mais pas de changement entre ces deux ticks donc pas de lignes supplémentaires)
# - tick 85432 : Changement de side mi-temps du match
# - tick 211293 : Changement de side Overtime

# %%
# Team_V2 = demo1.parse_event('player_team')
# Team_V2.sort_values(by=['tick','team'],inplace=True)
# Team_V2['team_name'] = np.where(Team_V2['user_name'].isin(zobrux),'Zobrux','Opposing_team')
# Team_V2['side'] = np.where(Team_V2['team'] == 2,'T','CT')
# Team_V2.drop(['disconnect','isbot','oldteam','silent','user_steamid'],axis=1,inplace=True)
# Team_V2.rename(columns={"user_name":"name"},inplace=True)

# %%
# Team_V2.head()

# %%
team_V3 = demo1.parse_ticks(["team_clan_name","team_name"])
team_V3.drop(team_V3[team_V3['tick'] < first_round_tick].index, inplace=True)
team_V3.drop(team_V3[team_V3['tick'] > max_tick].index, inplace=True)
team_V3.rename(columns={'team_name':'side'},inplace=True)

# %%
team_V3
# Out:
#               side team_clan_name    tick            steamid          name
# 32310    TERRORIST         zobrux    3237  76561198111191178     -silentGG
# 32311           CT      KREATURES    3237  76561198264064168  JustAnotherL
# 32312    TERRORIST         zobrux    3237  76561198066661071      OzzieOzz
# 32313    TERRORIST         zobrux    3237  76561198259827471    godofbaldz
# 32314           CT      KREATURES    3237  76561199198706117    ADEODATUSS
# ...            ...            ...     ...                ...           ...
# 2359395  TERRORIST         zobrux  236075  76561198376612283     BELDIYA00
# 2359396         CT      KREATURES  236075  76561198014090099        fykseN
# 2359397         CT      KREATURES  236075  76561198358546254      MasaIDK_
# 2359398  TERRORIST         zobrux  236075  76561198173360875      Spiritix
# 2359399         CT      KREATURES  236075  76561199074956403   3PARABELLUM
#
# [2327090 rows x 5 columns]

# %% [markdown]
# il semblerait que team 2 = Terrorist et team 3 = CT

# %% [markdown]
# #### Table Round winner

# %%
round_ends = demo1.parse_event("round_end", other=["total_rounds_played"])
round_ends.drop(round_ends[round_ends['tick'] <= first_round_tick].index, inplace=True)
round_ends.drop(columns={'round'}, inplace=True)

# %%
round_ends
# Out:
#            reason    tick  total_rounds_played winner
# 1    bomb_defused    8686                    1     CT
# 2       ct_killed   14957                    2      T
# 3       ct_killed   21292                    3      T
# 4       ct_killed   26165                    4      T
# 5        t_killed   32190                    5     CT
# 6   bomb_exploded   40624                    6      T
# 7        t_killed   47409                    7     CT
# 8   bomb_exploded   57244                    8      T
# 9       ct_killed   63141                    9      T
# 10      ct_killed   67688                   10      T
# 11      ct_killed   76616                   11      T
# 12      ct_killed   84888                   12      T
# 13      ct_killed   90245                   13      T
# 14      ct_killed   98136                   14      T
# 15      ct_killed  107073                   15      T
# 16      ct_killed  112810                   16      T
# 17  bomb_exploded  122044                   17      T
# 18      ct_killed  130380                   18      T
# 19      ct_killed  138526                   19      T
# 20       t_killed  146127                   20     CT
# 21  bomb_exploded  156367                   21      T
# 22       t_killed  164535                   22     CT
# 23   bomb_defused  175678                   23     CT
# 24      ct_killed  184735                   24      T
# 25       t_killed  193601                   25     CT
# 26      ct_killed  201977                   26      T
# 27      ct_killed  210749                   27      T
# 28      ct_killed  219837                   28      T
# 29      ct_killed  228961                   29      T
# 30      ct_killed  236075                   30      T

# %% [markdown]
# #### Table kills

# %%
kills_df = demo1.parse_event("player_death", player=["X", "Y"], other=["total_rounds_played"])

# %%
kills_df.columns
# Out:
# Index(['assistedflash', 'assister_X', 'assister_Y', 'assister_name',
#        'assister_steamid', 'attacker_X', 'attacker_Y', 'attacker_name',
#        'attacker_steamid', 'attackerblind', 'distance', 'dmg_armor',
#        'dmg_health', 'dominated', 'headshot', 'hitgroup', 'noreplay',
#        'noscope', 'penetrated', 'revenge', 'thrusmoke', 'tick',
#        'total_rounds_played', 'user_X', 'user_Y', 'user_name', 'user_steamid',
#        'weapon', 'weapon_fauxitemid', 'weapon_itemid',
#        'weapon_originalowner_xuid', 'wipe'],
#       dtype='object')

# %%
kills_df
# Out:
#      assistedflash  assister_X  assister_Y assister_name   assister_steamid  \
# 0            False -167.055969  237.575424      Spiritix  76561198173360875
# 1            False -122.406067  180.313324  JustAnotherL  76561198264064168
# 2            False  -52.514343  267.781067     BELDIYA00  76561198376612283
# 3            False  -37.319031  106.022820   3PARABELLUM  76561199074956403
# 4            False -199.968750  154.260818      MasaIDK_  76561198358546254
# ..             ...         ...         ...           ...                ...
# 204          False         NaN         NaN          None               None
# 205          False         NaN         NaN          None               None
# 206          False         NaN         NaN          None               None
# 207          False         NaN         NaN          None               None
# 208          False         NaN         NaN          None               None
#
#       attacker_X   attacker_Y attacker_name   attacker_steamid  attackerblind  \
# 0    -199.970703   259.122498      OzzieOzz  76561198066661071          False
# 1     -90.374817   180.395264    ADEODATUSS  76561199198706117          False
# 2     -50.618103   138.054077    godofbaldz  76561198259827471          False
# 3     -60.121765   136.473846    ADEODATUSS  76561199198706117          False
# 4    -153.121460   136.579834  JustAnotherL  76561198264064168          False
# ..           ...          ...           ...                ...            ...
# 204 -1843.828613     7.268648    godofbaldz  76561198259827471          False
# 205 -1903.309448   284.353912    godofbaldz  76561198259827471          False
# 206 -1827.925171   112.288429    godofbaldz  76561198259827471          False
# 207  -891.219482   320.774597      OzzieOzz  76561198066661071          False
# 208  -591.338745  2153.288330     BELDIYA00  76561198376612283          False
#
#      ...  total_rounds_played       user_X       user_Y     user_name  \
# 0    ...                    0  -199.327637   210.264328        fykseN
# 1    ...                    0  -100.432251   212.426514     -silentGG
# 2    ...                    0   -37.088135   106.022820   3PARABELLUM
# 3    ...                    0   -72.574768   172.412903     BELDIYA00
# 4    ...                    0  -101.537781   164.830856      Spiritix
# ..   ...                  ...          ...          ...           ...
# 204  ...                   29 -1211.707642   998.469543      MasaIDK_
# 205  ...                   29  -639.289856   701.306396    ADEODATUSS
# 206  ...                   29 -1188.051514   985.835938  JustAnotherL
# 207  ...                   29  -971.060059  1109.107056        fykseN
# 208  ...                   29  -972.507690  1519.204834   3PARABELLUM
#
#           user_steamid           weapon     weapon_fauxitemid  weapon_itemid  \
# 0    76561198014090099  knife_butterfly  17293822569105523203    35477304051
# 1    76561198111191178          knife_t  17293822569102704699              0
# 2    76561199074956403   knife_skeleton  17293822569103491597    35167355779
# 3    76561198376612283          knife_t  17293822569102704699              0
# 4    76561198173360875   knife_stiletto  17293822569106571786    34873144654
# ..                 ...              ...                   ...            ...
# 204  76561198358546254              awp  17293822569116598281    33914766179
# 205  76561199198706117              awp  17293822569116598281    33914766179
# 206  76561198264064168              awp  17293822569116598281    33914766179
# 207  76561198014090099             ak47  17293822569133768711    35297643185
# 208  76561199074956403             ak47  17293822569102704647    35774257056
#
#      weapon_originalowner_xuid  wipe
# 0                                  0
# 1                                  0
# 2                                  0
# 3                                  0
# 4                                  0
# ..                         ...   ...
# 204                                0
# 205                                0
# 206                                0
# 207                                0
# 208                                0
#
# [209 rows x 32 columns]

# %% [markdown]
# #### Table Eco

# %%
eco = demo1.parse_ticks(["current_equip_value", "total_rounds_played"], ticks=freezetime_end_tick)

# %%
eco
# Out:
#      total_rounds_played  current_equip_value    tick            steamid  \
# 0                      0                  850    4933  76561198111191178
# 1                      0                  850    4933  76561198264064168
# 2                      0                 1150    4933  76561198066661071
# 3                      0                  850    4933  76561198259827471
# 4                      0                  850    4933  76561199198706117
# ..                   ...                  ...     ...                ...
# 295                   29                 5100  230689  76561198376612283
# 296                   29                 3650  230689  76561198014090099
# 297                   29                 5500  230689  76561198358546254
# 298                   29                 5100  230689  76561198173360875
# 299                   29                 5150  230689  76561199074956403
#
#              name
# 0       -silentGG
# 1    JustAnotherL
# 2        OzzieOzz
# 3      godofbaldz
# 4      ADEODATUSS
# ..            ...
# 295     BELDIYA00
# 296        fykseN
# 297      MasaIDK_
# 298      Spiritix
# 299   3PARABELLUM
#
# [300 rows x 5 columns]

# %% [markdown]
# La fonction "total_rounds_played" démarre de 0 a 29 on va y ajouter 1 pour que ça corresponde aux rounds de notre partie

# %%
eco['total_rounds_played'] = eco['total_rounds_played'] + 1

# %% [markdown]
# la fonction "current_equip_value" compte la valeur du glock (T) et de l'usp (CT) dans la valeur totale il faut donc la supprimer

# %%
eco['current_equip_value'] = eco['current_equip_value'] - 200

# %%
eco
# Out:
#      total_rounds_played  current_equip_value    tick            steamid  \
# 0                      1                  650    4933  76561198111191178
# 1                      1                  650    4933  76561198264064168
# 2                      1                  950    4933  76561198066661071
# 3                      1                  650    4933  76561198259827471
# 4                      1                  650    4933  76561199198706117
# ..                   ...                  ...     ...                ...
# 295                   30                 4900  230689  76561198376612283
# 296                   30                 3450  230689  76561198014090099
# 297                   30                 5300  230689  76561198358546254
# 298                   30                 4900  230689  76561198173360875
# 299                   30                 4950  230689  76561199074956403
#
#              name
# 0       -silentGG
# 1    JustAnotherL
# 2        OzzieOzz
# 3      godofbaldz
# 4      ADEODATUSS
# ..            ...
# 295     BELDIYA00
# 296        fykseN
# 297      MasaIDK_
# 298      Spiritix
# 299   3PARABELLUM
#
# [300 rows x 5 columns]

# %% [markdown]
# On va enrichir avec les notions d'équipe et de side

# %%
eco_by_players = pd.merge(eco,team_V3, on=['tick','name','steamid'])

# %%
eco_by_players
# Out:
#      total_rounds_played  current_equip_value    tick            steamid  \
# 0                      1                  650    4933  76561198111191178
# 1                      1                  650    4933  76561198264064168
# 2                      1                  950    4933  76561198066661071
# 3                      1                  650    4933  76561198259827471
# 4                      1                  650    4933  76561199198706117
# ..                   ...                  ...     ...                ...
# 295                   30                 4900  230689  76561198376612283
# 296                   30                 3450  230689  76561198014090099
# 297                   30                 5300  230689  76561198358546254
# 298                   30                 4900  230689  76561198173360875
# 299                   30                 4950  230689  76561199074956403
#
#              name       side team_clan_name
# 0       -silentGG  TERRORIST         zobrux
# 1    JustAnotherL         CT      KREATURES
# 2        OzzieOzz  TERRORIST         zobrux
# 3      godofbaldz  TERRORIST         zobrux
# 4      ADEODATUSS         CT      KREATURES
# ..            ...        ...            ...
# 295     BELDIYA00  TERRORIST         zobrux
# 296        fykseN         CT      KREATURES
# 297      MasaIDK_         CT      KREATURES
# 298      Spiritix  TERRORIST         zobrux
# 299   3PARABELLUM         CT      KREATURES
#
# [300 rows x 7 columns]

# %% [markdown]
# On va également enrichir a l'aide des notions de round winner et win_reason

# %%
eco_by_players = pd.merge_asof(eco_by_players,round_ends[['tick','winner','reason']], on='tick', direction='forward')

# %%
eco_by_players
# Out:
#      total_rounds_played  current_equip_value    tick            steamid  \
# 0                      1                  650    4933  76561198111191178
# 1                      1                  650    4933  76561198264064168
# 2                      1                  950    4933  76561198066661071
# 3                      1                  650    4933  76561198259827471
# 4                      1                  650    4933  76561199198706117
# ..                   ...                  ...     ...                ...
# 295                   30                 4900  230689  76561198376612283
# 296                   30                 3450  230689  76561198014090099
# 297                   30                 5300  230689  76561198358546254
# 298                   30                 4900  230689  76561198173360875
# 299                   30                 4950  230689  76561199074956403
#
#              name       side team_clan_name winner        reason
# 0       -silentGG  TERRORIST         zobrux     CT  bomb_defused
# 1    JustAnotherL         CT      KREATURES     CT  bomb_defused
# 2        OzzieOzz  TERRORIST         zobrux     CT  bomb_defused
# 3      godofbaldz  TERRORIST         zobrux     CT  bomb_defused
# 4      ADEODATUSS         CT      KREATURES     CT  bomb_defused
# ..            ...        ...            ...    ...           ...
# 295     BELDIYA00  TERRORIST         zobrux      T     ct_killed
# 296        fykseN         CT      KREATURES      T     ct_killed
# 297      MasaIDK_         CT      KREATURES      T     ct_killed
# 298      Spiritix  TERRORIST         zobrux      T     ct_killed
# 299   3PARABELLUM         CT      KREATURES      T     ct_killed
#
# [300 rows x 9 columns]

# %% [markdown]
# On va grouper par team pour avoir l'infos également

# %%
eco_by_team = eco_by_players.groupby(['total_rounds_played','team_clan_name','tick','side','winner','reason'])['current_equip_value'].sum().reset_index()

# %%
eco_by_team.head()
# Out:
#    total_rounds_played team_clan_name   tick       side winner        reason  \
# 0                    1      KREATURES   4933         CT     CT  bomb_defused
# 1                    1         zobrux   4933  TERRORIST     CT  bomb_defused
# 2                    2      KREATURES  10414         CT      T     ct_killed
# 3                    2         zobrux  10414  TERRORIST      T     ct_killed
# 4                    3      KREATURES  18605         CT      T     ct_killed
#
#    current_equip_value
# 0                 3250
# 1                 3600
# 2                19850
# 3                15000
# 4                 7500

# %% [markdown]
# ## Calculs des KPI

# %% [markdown]
# #### Analyse par joueurs

# %% [markdown]
# ##### Stats kills

# %%
kills_df = demo1.parse_event("player_death", other=["total_rounds_played"])
kills_df = kills_df[kills_df['tick'] >= first_round_tick]
kills_df['total_rounds_played'] = kills_df['total_rounds_played'] + 1

# %%
# on enrichie avec l'équipe et le side du tueur
kills_df = pd.merge(kills_df,team_V3, left_on=['tick','attacker_name'],right_on=['tick','name'])

# %%
kills_df = kills_df.rename(columns={'team_clan_name':'attacker_team_name','side':'attacker_side'})
kills_df = kills_df.drop(columns=['name','steamid'])

# %%
# on enrichie avec l'équipe et le side du tué
kills_df = pd.merge(kills_df,team_V3, left_on=['tick','user_name'],right_on=['tick','name'])

# %%
kills_df = kills_df.rename(columns={'team_clan_name':'user_team_name','side':'user_side'})
kills_df = kills_df.drop(columns=['name','steamid'])

# %%
df_global = kills_df.merge(eco_by_players, left_on=['total_rounds_played','attacker_name'], right_on=['total_rounds_played','name'])

# %%
df_global['map'] = demo1.parse_header()['map_name']

# %%
df_global.head()
# Out:
#    assistedflash assister_name   assister_steamid attacker_name  \
# 0          False          None               None  JustAnotherL
# 1          False  JustAnotherL  76561198264064168      MasaIDK_
# 2          False          None               None      OzzieOzz
# 3          False          None               None     BELDIYA00
# 4          False          None               None    godofbaldz
#
#     attacker_steamid  attackerblind   distance  dmg_armor  dmg_health  \
# 0  76561198264064168          False  16.071526          0         124
# 1  76561198358546254          False  10.993015          0         129
# 2  76561198066661071          False  17.510454          0          96
# 3  76561198376612283          False  14.075491          0         101
# 4  76561198259827471          False   5.924605          9          17
#
#    dominated  ...  user_team_name  current_equip_value  tick_y  \
# 0          0  ...          zobrux                  650    4933
# 1          0  ...          zobrux                  650    4933
# 2          0  ...       KREATURES                  950    4933
# 3          0  ...       KREATURES                  650    4933
# 4          0  ...       KREATURES                  650    4933
#
#              steamid          name       side  team_clan_name  winner  \
# 0  76561198264064168  JustAnotherL         CT       KREATURES      CT
# 1  76561198358546254      MasaIDK_         CT       KREATURES      CT
# 2  76561198066661071      OzzieOzz  TERRORIST          zobrux      CT
# 3  76561198376612283     BELDIYA00  TERRORIST          zobrux      CT
# 4  76561198259827471    godofbaldz  TERRORIST          zobrux      CT
#
#          reason        map
# 0  bomb_defused  de_anubis
# 1  bomb_defused  de_anubis
# 2  bomb_defused  de_anubis
# 3  bomb_defused  de_anubis
# 4  bomb_defused  de_anubis
#
# [5 rows x 39 columns]

# %%
df_global.columns
# Out:
# Index(['assistedflash', 'assister_name', 'assister_steamid', 'attacker_name',
#        'attacker_steamid', 'attackerblind', 'distance', 'dmg_armor',
#        'dmg_health', 'dominated', 'headshot', 'hitgroup', 'noreplay',
#        'noscope', 'penetrated', 'revenge', 'thrusmoke', 'tick_x',
#        'total_rounds_played', 'user_name', 'user_steamid', 'weapon',
#        'weapon_fauxitemid', 'weapon_itemid', 'weapon_originalowner_xuid',
#        'wipe', 'attacker_side', 'attacker_team_name', 'user_side',
#        'user_team_name', 'current_equip_value', 'tick_y', 'steamid', 'name',
#        'side', 'team_clan_name', 'winner', 'reason', 'map'],
#       dtype='object')

# %% [markdown]
# #### Extraction des infos spécifique depuis le demo1 event

# %% [markdown]
# ##### Trade

# %%
trade = demo1.parse_event("player_death", other=["game_time", "round_start_time",'total_rounds_played'])
trade.drop(trade[trade['tick'] < first_round_tick].index, inplace=True)
trade["player_died_time"] = trade["game_time"] - trade["round_start_time"]
trade
trade  = pd.merge(trade,team_V3[['team_clan_name','side','name','tick']], left_on=["attacker_name",'tick'], right_on=['name','tick'])
trade
trade = trade.rename(columns={'team_clan_name':'team_clan_name_attacker','side':'side_attacker'})
trade  = pd.merge(trade,team_V3[['team_clan_name','side','name','tick']], left_on=["user_name",'tick'], right_on=['name','tick'])
trade = trade.rename(columns={'team_clan_name':'team_clan_name_user','side':'side_user'})
trade = trade.loc[:, ["total_rounds_played","tick","attacker_name","user_name",'team_clan_name_user',"side_user","player_died_time"]]
trade.head(30)
# Out:
#     total_rounds_played   tick attacker_name     user_name  \
# 0                     0   6171  JustAnotherL     -silentGG
# 1                     0   6252      MasaIDK_      Spiritix
# 2                     0   6407      OzzieOzz        fykseN
# 3                     0   6484     BELDIYA00  JustAnotherL
# 4                     0   6622    godofbaldz      MasaIDK_
# 5                     0   7119   3PARABELLUM      OzzieOzz
# 6                     0   7505    ADEODATUSS    godofbaldz
# 7                     0   7808     BELDIYA00    ADEODATUSS
# 8                     0   7841   3PARABELLUM     BELDIYA00
# 9                     1  12878      Spiritix    ADEODATUSS
# 10                    1  13088     -silentGG  JustAnotherL
# 11                    1  13694   3PARABELLUM     -silentGG
# 12                    1  14704      OzzieOzz        fykseN
# 13                    1  14773      MasaIDK_    godofbaldz
# 14                    1  14805      OzzieOzz      MasaIDK_
# 15                    1  14957      OzzieOzz   3PARABELLUM
# 16                    2  19404      Spiritix   3PARABELLUM
# 17                    2  19423      Spiritix    ADEODATUSS
# 18                    2  20461    godofbaldz  JustAnotherL
# 19                    2  20826      Spiritix      MasaIDK_
# 20                    2  21277        fykseN     -silentGG
# 21                    2  21292    godofbaldz        fykseN
# 22                    3  24552     -silentGG        fykseN
# 23                    3  25106    godofbaldz      MasaIDK_
# 24                    3  25216    godofbaldz  JustAnotherL
# 25                    3  25327    godofbaldz    ADEODATUSS
# 26                    3  26165     BELDIYA00   3PARABELLUM
# 27                    4  28801      MasaIDK_     -silentGG
# 28                    4  29049      Spiritix      MasaIDK_
# 29                    4  29148     BELDIYA00        fykseN
#
#    team_clan_name_user  side_user  player_died_time
# 0               zobrux  TERRORIST         19.328125
# 1               zobrux  TERRORIST         20.593750
# 2            KREATURES         CT         23.015625
# 3            KREATURES         CT         24.218750
# 4            KREATURES         CT         26.375000
# 5               zobrux  TERRORIST         34.140625
# 6               zobrux  TERRORIST         40.171875
# 7            KREATURES         CT         44.906250
# 8               zobrux  TERRORIST         45.421875
# 9            KREATURES         CT         38.484375
# 10           KREATURES         CT         41.765625
# 11              zobrux  TERRORIST         51.234375
# 12           KREATURES         CT         67.015625
# 13              zobrux  TERRORIST         68.093750
# 14           KREATURES         CT         68.593750
# 15           KREATURES         CT         70.968750
# 16           KREATURES         CT         12.468750
# 17           KREATURES         CT         12.765625
# 18           KREATURES         CT         28.984375
# 19           KREATURES         CT         34.687500
# 20              zobrux  TERRORIST         41.734375
# 21           KREATURES         CT         41.968750
# 22           KREATURES         CT         23.921875
# 23           KREATURES         CT         32.578125
# 24           KREATURES         CT         34.296875
# 25           KREATURES         CT         36.031250
# 26           KREATURES         CT         49.125000
# 27              zobrux  TERRORIST         14.171875
# 28           KREATURES         CT         18.046875
# 29           KREATURES         CT         19.593750

# %%
# Initialiser des dictionnaires pour stocker les traded deaths et trade kills par joueur
traded_deaths = {}
trade_kills = {}

# Parcourir toutes les lignes du DataFrame pour chercher les morts des terroristes
for i, row in trade.iterrows():
    if row['side_user'] == 'TERRORIST':
        # Extraire les informations de la ligne courante
        terrorist_name = row['user_name']
        attacker_name = row['attacker_name']
        death_time = row['player_died_time']
        round_number = row['total_rounds_played']
        
        # Chercher si l'attaquant (CT) est tué dans les 2 secondes après avoir tué le terroriste
        subsequent_kills = trade[(trade['user_name'] == attacker_name) & 
                                 (trade['player_died_time'] > death_time) & 
                                 (trade['player_died_time'] <= death_time + 2)]
        
        # Si un traded death est trouvé
        if not subsequent_kills.empty:
            # Assurer que la mort de l'attaquant se produit dans le même round que la mort du terroriste
            if all(subsequent_kills['total_rounds_played'] == round_number):
                if terrorist_name not in traded_deaths:
                    traded_deaths[terrorist_name] = {'count': 0, 'rounds': []}
                traded_deaths[terrorist_name]['count'] += 1
                traded_deaths[terrorist_name]['rounds'].append(round_number)

                # Chercher si le trade kill vient d'un coéquipier du terroriste
                for _, sub_kill in subsequent_kills.iterrows():
                    trade_killer = sub_kill['attacker_name']
                    if trade_killer != terrorist_name:
                        if trade_killer not in trade_kills:
                            trade_kills[trade_killer] = {'count': 0, 'rounds': []}
                        trade_kills[trade_killer]['count'] += 1
                        trade_kills[trade_killer]['rounds'].append(round_number)

# Convertir les dictionnaires en DataFrames pour afficher les résultats
traded_deaths_list = [(player, data['count']) for player, data in traded_deaths.items()]
trade_kills_list = [(player, data['count']) for player, data in trade_kills.items()]

traded_deaths_df = pd.DataFrame(traded_deaths_list, columns=['name', 'Traded Deaths'])
trade_kills_df = pd.DataFrame(trade_kills_list, columns=['name', 'Trade Kills'])

# Afficher les résultats
traded_deaths_df
# Out:
#            name  Traded Deaths
# 0    godofbaldz              2
# 1     -silentGG              3
# 2      OzzieOzz              1
# 3  JustAnotherL              4
# 4        fykseN              2
# 5   3PARABELLUM              2
# 6      MasaIDK_              1
# 7    ADEODATUSS              1

# %%
trade_kills_df
# Out:
#            name  Trade Kills
# 0      OzzieOzz            2
# 1    godofbaldz            1
# 2     -silentGG            1
# 3        fykseN            1
# 4    ADEODATUSS            5
# 5  JustAnotherL            2
# 6      MasaIDK_            1
# 7   3PARABELLUM            1
# 8     BELDIYA00            2

# %% [markdown]
# ##### Utils efficency

# %%
utils_stats = ["total_rounds_played","utility_damage_total","enemies_flashed_total"]

stats_utils = demo1.parse_ticks(utils_stats, ticks=[max_tick])
stats_utils = stats_utils.rename(columns={"utility_damage_total":"Utility Damages","enemies_flashed_total":"Flashed Ennemies"})
stats_utils = stats_utils.drop(columns={"tick"})
nouvel_ordre_colonnes = [
    'name', 'steamid', "Utility Damages","Flashed Ennemies"
]
stats_utils = stats_utils[nouvel_ordre_colonnes]
stats_utils
# Out:
#            name            steamid  Utility Damages  Flashed Ennemies
# 0     -silentGG  76561198111191178              175                 7
# 1  JustAnotherL  76561198264064168              106                13
# 2      OzzieOzz  76561198066661071               75                 5
# 3    godofbaldz  76561198259827471               79                14
# 4    ADEODATUSS  76561199198706117               34                 9
# 5     BELDIYA00  76561198376612283              257                 6
# 6        fykseN  76561198014090099              163                 8
# 7      MasaIDK_  76561198358546254               85                 3
# 8      Spiritix  76561198173360875              230                 2
# 9   3PARABELLUM  76561199074956403              166                11

# %% [markdown]
# Flash assist

# %%
flash_assist_count = df_global[df_global['assistedflash'] == True].groupby('assister_name').size().reset_index(name='Flash_assist')
flash_assist_count = flash_assist_count.rename(columns={'assister_name':'name'})
flash_assist_count
# Out:
#            name  Flash_assist
# 0    ADEODATUSS             1
# 1  JustAnotherL             1
# 2    godofbaldz             1

# %% [markdown]
# ##### Opening duels

# %%
# Identifier le premier kill de chaque round
first_duel = trade.groupby('total_rounds_played').first().reset_index()

# %%
first_duel
# Out:
#     total_rounds_played    tick attacker_name     user_name  \
# 0                     0    6171  JustAnotherL     -silentGG
# 1                     1   12878      Spiritix    ADEODATUSS
# 2                     2   19404      Spiritix   3PARABELLUM
# 3                     3   24552     -silentGG        fykseN
# 4                     4   28801      MasaIDK_     -silentGG
# 5                     5   34832    godofbaldz  JustAnotherL
# 6                     6   43818  JustAnotherL    godofbaldz
# 7                     7   51119    godofbaldz    ADEODATUSS
# 8                     8   60808      OzzieOzz  JustAnotherL
# 9                     9   66126     BELDIYA00  JustAnotherL
# 10                   10   73087   3PARABELLUM    godofbaldz
# 11                   11   84317        fykseN      OzzieOzz
# 12                   12   90026   3PARABELLUM      OzzieOzz
# 13                   13   96043      MasaIDK_    godofbaldz
# 14                   14  105423     BELDIYA00   3PARABELLUM
# 15                   15  110825   3PARABELLUM      Spiritix
# 16                   16  118905  JustAnotherL      OzzieOzz
# 17                   17  125806    ADEODATUSS      OzzieOzz
# 18                   18  133015   3PARABELLUM      Spiritix
# 19                   19  142386      Spiritix        fykseN
# 20                   20  152596    godofbaldz   3PARABELLUM
# 21                   21  159724    godofbaldz   3PARABELLUM
# 22                   22  173731     BELDIYA00   3PARABELLUM
# 23                   23  181441     -silentGG  JustAnotherL
# 24                   24  192132    godofbaldz  JustAnotherL
# 25                   25  195899        fykseN    godofbaldz
# 26                   26  207983        fykseN      OzzieOzz
# 27                   27  216798        fykseN      Spiritix
# 28                   28  226570    godofbaldz  JustAnotherL
# 29                   29  231588    godofbaldz      MasaIDK_
#
#    team_clan_name_user  side_user  player_died_time
# 0               zobrux  TERRORIST         19.328125
# 1            KREATURES         CT         38.484375
# 2            KREATURES         CT         12.468750
# 3            KREATURES         CT         23.921875
# 4               zobrux  TERRORIST         14.171875
# 5            KREATURES         CT         14.265625
# 6               zobrux  TERRORIST         22.890625
# 7            KREATURES         CT         30.953125
# 8            KREATURES         CT         28.671875
# 9            KREATURES         CT         19.625000
# 10              zobrux  TERRORIST         57.343750
# 11              zobrux  TERRORIST         93.312500
# 12              zobrux         CT         45.265625
# 13              zobrux         CT         63.578125
# 14           KREATURES  TERRORIST         86.843750
# 15              zobrux         CT         31.609375
# 16              zobrux         CT         68.218750
# 17              zobrux         CT         31.765625
# 18              zobrux         CT         14.156250
# 19           KREATURES  TERRORIST         33.296875
# 20           KREATURES  TERRORIST         74.062500
# 21           KREATURES  TERRORIST         25.437500
# 22           KREATURES  TERRORIST         69.875000
# 23           KREATURES  TERRORIST         17.312500
# 24           KREATURES  TERRORIST         80.562500
# 25              zobrux         CT          8.890625
# 26              zobrux         CT         66.828125
# 27              zobrux  TERRORIST         59.500000
# 28           KREATURES         CT         78.187500
# 29           KREATURES         CT         14.031250

# %%
# Initialiser un DataFrame pour stocker les résultats par joueur
opening_stats = pd.DataFrame({
    'name': trade['attacker_name'].unique(),
    'entry_attempts(T)': 0,
    'entry_successes(T)': 0,
    'open_attempts(CT)': 0,
    'open_successes(CT)': 0
})

# Parcourir chaque premier kill pour déterminer si c'est une tentative d'entry (T) ou d'open (CT)
for _, row in first_duel.iterrows():
    attacker = row['attacker_name']
    user = row['user_name']
    side_user = row['side_user']

    # Si le joueur tué est un CT, c'est une tentative d'entry pour un Terrorist
    if side_user == 'CT':
        # C'est une tentative d'entry pour l'attaquant
        opening_stats.loc[opening_stats['name'] == attacker, 'entry_attempts(T)'] += 1
        opening_stats.loc[opening_stats['name'] == attacker, 'entry_successes(T)'] += 1
        opening_stats.loc[opening_stats['name'] == user, 'open_attempts(CT)'] += 1


    # Si le joueur tué est un Terroriste, c'est une tentative d'open pour un CT
    elif side_user == 'TERRORIST':
        # C'est une tentative d'open pour l'attaquant
        opening_stats.loc[opening_stats['name'] == attacker, 'open_attempts(CT)'] += 1
        opening_stats.loc[opening_stats['name'] == attacker, 'open_successes(CT)'] += 1
        opening_stats.loc[opening_stats['name'] == user, 'entry_attempts(T)'] += 1

        

# Afficher le résultat
opening_stats
# Out:
#            name  entry_attempts(T)  entry_successes(T)  open_attempts(CT)  \
# 0  JustAnotherL                  3                   1                  6
# 1      MasaIDK_                  1                   1                  2
# 2      OzzieOzz                  2                   1                  4
# 3     BELDIYA00                  1                   1                  2
# 4    godofbaldz                  6                   4                  5
# 5   3PARABELLUM                  7                   3                  2
# 6    ADEODATUSS                  1                   1                  2
# 7      Spiritix                  3                   2                  3
# 8     -silentGG                  3                   1                  1
# 9        fykseN                  3                   2                  3
#
#    open_successes(CT)
# 0                   2
# 1                   1
# 2                   0
# 3                   2
# 4                   3
# 5                   1
# 6                   0
# 7                   1
# 8                   1
# 9                   2

# %%
opening_stats["%_entry_success(T)"] = round((opening_stats["entry_successes(T)"] / opening_stats["entry_attempts(T)"])*100,0)
opening_stats["%_open_success(CT)"] = round((opening_stats["open_successes(CT)"] / opening_stats["open_attempts(CT)"])*100,0)

# %%
column_order=['name','entry_attempts(T)','entry_successes(T)','%_entry_success(T)','open_attempts(CT)','open_successes(CT)','%_open_success(CT)']
opening_stats = opening_stats[column_order]

# %%
opening_stats
# Out:
#            name  entry_attempts(T)  entry_successes(T)  %_entry_success(T)  \
# 0  JustAnotherL                  3                   1                33.0
# 1      MasaIDK_                  1                   1               100.0
# 2      OzzieOzz                  2                   1                50.0
# 3     BELDIYA00                  1                   1               100.0
# 4    godofbaldz                  6                   4                67.0
# 5   3PARABELLUM                  7                   3                43.0
# 6    ADEODATUSS                  1                   1               100.0
# 7      Spiritix                  3                   2                67.0
# 8     -silentGG                  3                   1                33.0
# 9        fykseN                  3                   2                67.0
#
#    open_attempts(CT)  open_successes(CT)  %_open_success(CT)
# 0                  6                   2                33.0
# 1                  2                   1                50.0
# 2                  4                   0                 0.0
# 3                  2                   2               100.0
# 4                  5                   3                60.0
# 5                  2                   1                50.0
# 6                  2                   0                 0.0
# 7                  3                   1                33.0
# 8                  1                   1               100.0
# 9                  3                   2                67.0

# %% [markdown]
# ##### Clutchs

# %%
df_global.columns
# Out:
# Index(['assistedflash', 'assister_name', 'assister_steamid', 'attacker_name',
#        'attacker_steamid', 'attackerblind', 'distance', 'dmg_armor',
#        'dmg_health', 'dominated', 'headshot', 'hitgroup', 'noreplay',
#        'noscope', 'penetrated', 'revenge', 'thrusmoke', 'tick_x',
#        'total_rounds_played', 'user_name', 'user_steamid', 'weapon',
#        'weapon_fauxitemid', 'weapon_itemid', 'weapon_originalowner_xuid',
#        'wipe', 'attacker_side', 'attacker_team_name', 'user_side',
#        'user_team_name', 'current_equip_value', 'tick_y', 'steamid', 'name',
#        'side', 'team_clan_name', 'winner', 'reason', 'map'],
#       dtype='object')

# %%
df_global[['attacker_name','user_name','tick_x','total_rounds_played']].head(20)
# Out:
#    attacker_name     user_name  tick_x  total_rounds_played
# 0   JustAnotherL     -silentGG    6171                    1
# 1       MasaIDK_      Spiritix    6252                    1
# 2       OzzieOzz        fykseN    6407                    1
# 3      BELDIYA00  JustAnotherL    6484                    1
# 4     godofbaldz      MasaIDK_    6622                    1
# 5    3PARABELLUM      OzzieOzz    7119                    1
# 6     ADEODATUSS    godofbaldz    7505                    1
# 7      BELDIYA00    ADEODATUSS    7808                    1
# 8    3PARABELLUM     BELDIYA00    7841                    1
# 9       Spiritix    ADEODATUSS   12878                    2
# 10     -silentGG  JustAnotherL   13088                    2
# 11   3PARABELLUM     -silentGG   13694                    2
# 12      OzzieOzz        fykseN   14704                    2
# 13      MasaIDK_    godofbaldz   14773                    2
# 14      OzzieOzz      MasaIDK_   14805                    2
# 15      OzzieOzz   3PARABELLUM   14957                    2
# 16      Spiritix   3PARABELLUM   19404                    3
# 17      Spiritix    ADEODATUSS   19423                    3
# 18    godofbaldz  JustAnotherL   20461                    3
# 19      Spiritix      MasaIDK_   20826                    3

# %%
# Initialiser un DataFrame pour suivre les clutches
clutch_stats = pd.DataFrame(columns=["player_name", "ct_clutches_attempted", "ct_clutches_won", "t_clutches_attempted", "t_clutches_won"])
clutch_stats.set_index("player_name", inplace=True)

# Fonction pour mettre à jour les statistiques de clutch pour CT ou T
def update_clutch_stats(player_name, team, won):
    if player_name not in clutch_stats.index:
        clutch_stats.loc[player_name] = [0, 0, 0, 0]  # Initialiser avec 0 tentatives et 0 réussites
    
    if team == "CT":
        # Incrémenter les clutchs tentés pour CT
        clutch_stats.loc[player_name, "ct_clutches_attempted"] += 1
        if won:
            clutch_stats.loc[player_name, "ct_clutches_won"] += 1
    elif team == "TERRORIST":
        # Incrémenter les clutchs tentés pour T
        clutch_stats.loc[player_name, "t_clutches_attempted"] += 1
        if won:
            clutch_stats.loc[player_name, "t_clutches_won"] += 1

X = 1

def find_if_1vx(deaths, round_idx, round_ends, df, X):
    # Filtrer les décès correspondant au round actuel
    round_deaths = deaths[deaths["total_rounds_played"] == round_idx]
    
    if round_deaths.empty:
        return None
    
    # Filtrer les ticks du round
    subdf = df[df["tick"].isin(round_deaths["tick"].to_list())]

    # Vérifier que nous avons un vainqueur dans round_ends pour ce round
    round_winner_info = round_ends.loc[round_ends['total_rounds_played'] == round_idx]
    if round_winner_info.empty:
        print(f"No winner info for round {round_idx}, skipping...")
        return None

    # Débogage pour vérifier les informations de vainqueur
    round_winner = round_winner_info["winner"].values[0]
    print(f"Round {round_idx}: Winner is {round_winner}")

    # Suivre les joueurs vivants à chaque étape du round
    for tick in sorted(subdf["tick"].unique()):
        current_tick_df = subdf[subdf["tick"] == tick]
        ct_alive = current_tick_df[(current_tick_df["team_name"] == "CT") & (current_tick_df["is_alive"] == True)]
        t_alive = current_tick_df[(current_tick_df["team_name"] == "TERRORIST") & (current_tick_df["is_alive"] == True)]
        
        # Vérification de la condition 1vX
        if len(ct_alive) == 1 and len(t_alive) == X:
            print(f"Detected 1v{X} situation for CT in round {round_idx}")
            if round_winner == "CT":  # CT a gagné
                print(f"CT won the round in a 1v{X}")
                update_clutch_stats(ct_alive["name"].iloc[0], "CT", won=True)  # CT wins the clutch
                update_clutch_stats(t_alive["name"].iloc[0], "TERRORIST", won=False)  # T loses the clutch
            else:
                print(f"T won the round in a 1v{X}")
                update_clutch_stats(ct_alive["name"].iloc[0], "CT", won=False)  # CT loses the clutch
                update_clutch_stats(t_alive["name"].iloc[0], "TERRORIST", won=True)  # T wins the clutch
        elif len(t_alive) == 1 and len(ct_alive) == X:
            print(f"Detected 1v{X} situation for TERRORIST in round {round_idx}")
            if round_winner == "T":  # T a gagné
                print(f"T won the round in a 1v{X}")
                update_clutch_stats(t_alive["name"].iloc[0], "TERRORIST", won=True)  # T wins the clutch
                update_clutch_stats(ct_alive["name"].iloc[0], "CT", won=False)  # CT loses the clutch
            else:
                print(f"CT won the round in a 1v{X}")
                update_clutch_stats(t_alive["name"].iloc[0], "TERRORIST", won=False)  # T loses the clutch
                update_clutch_stats(ct_alive["name"].iloc[0], "CT", won=True)  # CT wins the clutch

# Chargement des événements avec la nouvelle colonne 'total_rounds_played'
deaths = demo1.parse_event("player_death", other=["total_rounds_played"])
deaths['total_rounds_played'] = deaths['total_rounds_played'] + 1
deaths.drop(deaths[deaths['tick'] <= first_round_tick].index, inplace=True)

round_ends = demo1.parse_event("round_end", other=["total_rounds_played"])
round_ends.drop(round_ends[round_ends['tick'] <= first_round_tick].index, inplace=True)

# Réinitialiser les indices de 'round_ends'
round_ends = round_ends.reset_index(drop=True)

df = demo1.parse_ticks(["is_alive", "team_name", "team_rounds_total"], ticks=deaths["tick"].to_list())
max_round = deaths["total_rounds_played"].max() + 1

# Parcourir tous les rounds
for round_idx in range(1, max_round):
    print(f"Checking for 1v{X} in round {round_idx}")
    clutcher_steamid = find_if_1vx(deaths, round_idx, round_ends, df, X)
    if clutcher_steamid is not None:
        print(f"Round: {round_idx} {clutcher_steamid} clutched a 1v{X}")

# Afficher le DataFrame final des statistiques de clutch
print(clutch_stats)
# Out:
# Checking for 1v1 in round 1
# Round 1: Winner is CT
# Detected 1v1 situation for CT in round 1
# CT won the round in a 1v1
# Checking for 1v1 in round 2
# Round 2: Winner is T
# Checking for 1v1 in round 3
# Round 3: Winner is T
# Checking for 1v1 in round 4
# Round 4: Winner is T
# Checking for 1v1 in round 5
# Round 5: Winner is CT
# Checking for 1v1 in round 6
# Round 6: Winner is T
# Checking for 1v1 in round 7
# Round 7: Winner is CT
# Detected 1v1 situation for CT in round 7
# CT won the round in a 1v1
# Checking for 1v1 in round 8
# Round 8: Winner is T
# Checking for 1v1 in round 9
# Round 9: Winner is T
# Checking for 1v1 in round 10
# Round 10: Winner is T
# Checking for 1v1 in round 11
# Round 11: Winner is T
# Detected 1v1 situation for CT in round 11
# T won the round in a 1v1
# Checking for 1v1 in round 12
# Round 12: Winner is T
# Checking for 1v1 in round 13
# Round 13: Winner is T
# Checking for 1v1 in round 14
# Round 14: Winner is T
# Checking for 1v1 in round 15
# Round 15: Winner is T
# Checking for 1v1 in round 16
# Round 16: Winner is T
# Checking for 1v1 in round 17
# Round 17: Winner is T
# Checking for 1v1 in round 18
# Round 18: Winner is T
# Checking for 1v1 in round 19
# Round 19: Winner is T
# Checking for 1v1 in round 20
# Round 20: Winner is CT
# Checking for 1v1 in round 21
# Round 21: Winner is T
# Checking for 1v1 in round 22
# Round 22: Winner is CT
# Checking for 1v1 in round 23
# Round 23: Winner is CT
# Checking for 1v1 in round 24
# Round 24: Winner is T
# Checking for 1v1 in round 25
# Round 25: Winner is CT
# Checking for 1v1 in round 26
# Round 26: Winner is T
# Checking for 1v1 in round 27
# Round 27: Winner is T
# Checking for 1v1 in round 28
# Round 28: Winner is T
# Detected 1v1 situation for CT in round 28
# T won the round in a 1v1
# Checking for 1v1 in round 29
# Round 29: Winner is T
# Detected 1v1 situation for CT in round 29
# T won the round in a 1v1
# Checking for 1v1 in round 30
# Round 30: Winner is T
#               ct_clutches_attempted  ct_clutches_won  t_clutches_attempted  \
# player_name
# 3PARABELLUM                       2                1                     0
# BELDIYA00                         0                0                     3
# ADEODATUSS                        2                1                     0
# Spiritix                          0                0                     1
# JustAnotherL                      1                0                     0
# OzzieOzz                          0                0                     1
#
#               t_clutches_won
# player_name
# 3PARABELLUM                0
# BELDIYA00                  2
# ADEODATUSS                 0
# Spiritix                   0
# JustAnotherL               0
# OzzieOzz                   1

# %%
clutch_stats
# Out:
#               ct_clutches_attempted  ct_clutches_won  t_clutches_attempted  \
# player_name
# 3PARABELLUM                       2                1                     0
# BELDIYA00                         0                0                     3
# ADEODATUSS                        2                1                     0
# Spiritix                          0                0                     1
# JustAnotherL                      1                0                     0
# OzzieOzz                          0                0                     1
#
#               t_clutches_won
# player_name
# 3PARABELLUM                0
# BELDIYA00                  2
# ADEODATUSS                 0
# Spiritix                   0
# JustAnotherL               0
# OzzieOzz                   1

# %% [markdown]
# #### Score d'eco

# %%
df_global.columns
# Out:
# Index(['assistedflash', 'assister_name', 'assister_steamid', 'attacker_name',
#        'attacker_steamid', 'attackerblind', 'distance', 'dmg_armor',
#        'dmg_health', 'dominated', 'headshot', 'hitgroup', 'noreplay',
#        'noscope', 'penetrated', 'revenge', 'thrusmoke', 'tick_x',
#        'total_rounds_played', 'user_name', 'user_steamid', 'weapon',
#        'weapon_fauxitemid', 'weapon_itemid', 'weapon_originalowner_xuid',
#        'wipe', 'attacker_side', 'attacker_team_name', 'user_side',
#        'user_team_name', 'current_equip_value', 'tick_y', 'steamid', 'name',
#        'side', 'team_clan_name', 'winner', 'reason', 'map'],
#       dtype='object')

# %%
#ANTI X KILLS EN FONCTION DE LA MONNAIE DE L'ADVERSAIRE'

# Fusionner les DataFrames sur les colonnes 'user_steamid' et 'steamid' et 'total_rounds_played'
df_merged = pd.merge(kills_df, eco_by_players, how='left', left_on=['attacker_name', 'total_rounds_played'], right_on=['name', 'total_rounds_played'])

# Filtrer les rounds 1 et 13 (pistol rounds) en les incluant dans une nouvelle catégorie
def categorize_kill(row):
    if row['total_rounds_played'] in [1, 13]:
        return 'pistol round'
    elif row['current_equip_value'] < 1000:
        return 'eco'
    elif row['current_equip_value'] < 3500:
        return 'force buy'
    else:
        return 'full buy'

# Appliquer la fonction de catégorisation
df_merged['kill_category'] = df_merged.apply(categorize_kill, axis=1)

# Utilisation de pivot_table pour compter les kills par catégorie et par joueur
pivot_df = df_merged.pivot_table(index='attacker_name', columns='kill_category', aggfunc='size', fill_value=0)

# Afficher le résultat
pivot_df
# Out:
# kill_category  eco  force buy  full buy  pistol round
# attacker_name
# -silentGG        1          2        14             0
# 3PARABELLUM      0          3        11             5
# ADEODATUSS       0          1        21             2
# BELDIYA00        0          1        24             2
# JustAnotherL     1          0        13             1
# MasaIDK_         1          5        12             1
# OzzieOzz         1          3        14             1
# Spiritix         0          1        17             0
# fykseN           2          2        12             1
# godofbaldz       3          0        21             2

# %%
#X KILLS EN FONCTION DE LA MONNAIE DE L'ADVERSAIRE'

# Fusionner les DataFrames sur les colonnes 'user_steamid' et 'steamid' et 'total_rounds_played'
df_merged = pd.merge(kills_df, eco_by_players, how='left', left_on=['user_name', 'total_rounds_played'], right_on=['name', 'total_rounds_played'])

# Filtrer les rounds 1 et 13 (pistol rounds) en les incluant dans une nouvelle catégorie
def categorize_kill(row):
    if row['total_rounds_played'] in [1, 13]:
        return 'pistol round'
    elif row['current_equip_value'] < 1000:
        return 'eco'
    elif row['current_equip_value'] < 3500:
        return 'force buy'
    else:
        return 'full buy'

# Appliquer la fonction de catégorisation
df_merged['kill_category'] = df_merged.apply(categorize_kill, axis=1)

# Utilisation de pivot_table pour compter les kills par catégorie et par joueur
pivot_df = df_merged.pivot_table(index='attacker_name', columns='kill_category', aggfunc='size', fill_value=0)

# Afficher le résultat
pivot_df
# Out:
# kill_category  eco  force buy  full buy  pistol round
# attacker_name
# -silentGG        1          3        13             0
# 3PARABELLUM      2          3         9             5
# ADEODATUSS       3          0        19             2
# BELDIYA00        4          2        19             2
# JustAnotherL     0          2        12             1
# MasaIDK_         5          2        11             1
# OzzieOzz         3          3        12             1
# Spiritix         2          8         8             0
# fykseN           1          1        14             1
# godofbaldz       3          3        18             2

# %%
# Fusionner les données de kills avec l'économie totale de l'équipe de l'attaquant
df_merged_team = pd.merge(kills_df, eco_by_team, how='left', left_on=['total_rounds_played', 'user_team_name'], right_on=['total_rounds_played', 'team_clan_name'])

# Filtrer les rounds 1 et 13 (pistol rounds) en les incluant dans une nouvelle catégorie
def categorize_kill(row):
    if row['total_rounds_played'] in [1, 13]:
        return 'Pistol round'
    elif row['current_equip_value'] <= 3500:
        return 'Anti eco kill'
    elif row['current_equip_value'] <= 18000:
        return 'Anti force buy kill'
    else:
        return 'Full buy kill'

# Appliquer la fonction de catégorisation
df_merged_team['kill_category'] = df_merged_team.apply(categorize_kill, axis=1)

# Utilisation de pivot_table pour compter les kills par catégorie et par joueur
pivot_df_team = df_merged_team.pivot_table(index='attacker_name', columns='kill_category', aggfunc='size', fill_value=0)

# Afficher le résultat
pivot_df_team
# Out:
# kill_category  Anti eco kill  Anti force buy kill  Full buy kill  Pistol round
# attacker_name
# -silentGG                  1                    2             14             0
# 3PARABELLUM                3                    2              9             5
# ADEODATUSS                 1                    2             19             2
# BELDIYA00                  3                    4             18             2
# JustAnotherL               0                    2             12             1
# MasaIDK_                   5                    1             12             1
# OzzieOzz                   2                    1             15             1
# Spiritix                   1                    8              9             0
# fykseN                     1                    0             15             1
# godofbaldz                 3                    2             19             2

# %%
# Fusionner les données de kills avec l'économie totale de l'équipe de l'attaquant
df_merged_team = pd.merge(kills_df, eco_by_team, how='left', left_on=['total_rounds_played', 'attacker_team_name'], right_on=['total_rounds_played', 'team_clan_name'])

# Filtrer les rounds 1 et 13 (pistol rounds) en les incluant dans une nouvelle catégorie
def categorize_kill(row):
    if row['total_rounds_played'] in [1, 13]:
        return 'Pistol round'
    elif row['current_equip_value'] <= 3500:
        return 'Eco kill'
    elif row['current_equip_value'] <= 18000:
        return 'Force buy kill'
    else:
        return 'Full buy kill'

# Appliquer la fonction de catégorisation
df_merged_team['kill_category'] = df_merged_team.apply(categorize_kill, axis=1)

# Utilisation de pivot_table pour compter les kills par catégorie et par joueur
pivot_df_team = df_merged_team.pivot_table(index='attacker_name', columns='kill_category', aggfunc='size', fill_value=0)

# Afficher le résultat
pivot_df_team
# Out:
# kill_category  Eco kill  Force buy kill  Full buy kill  Pistol round
# attacker_name
# -silentGG             1               1             15             0
# 3PARABELLUM           0               3             11             5
# ADEODATUSS            0               5             17             2
# BELDIYA00             1               0             24             2
# JustAnotherL          0               1             13             1
# MasaIDK_              0               1             17             1
# OzzieOzz              1               3             14             1
# Spiritix              0               1             17             0
# fykseN                1               3             12             1
# godofbaldz            0               3             21             2

# %% [markdown]
# #### Scoreboard

# %%
overall_stats = ["total_rounds_played","kills_total","assists_total","deaths_total", "mvps", "headshot_kills_total","3k_rounds_total", "4k_rounds_total", "ace_rounds_total" ,"damage_total","utility_damage_total","enemies_flashed_total","alive_time_total"]

stats = demo1.parse_ticks(overall_stats, ticks=[max_tick])
stats['ADR'] = round(stats['damage_total'] / stats["total_rounds_played"],2)
stats['HS %'] = round((stats['headshot_kills_total'] / stats['kills_total'])*100,2)
stats['KPR'] = round((stats['kills_total'] / stats['total_rounds_played']), 2)
stats['K/D'] = round((stats['kills_total'] / stats['deaths_total']),2)
stats = stats.rename(columns={"headshot_kills_total":"HS","kills_total":"Kills","assists_total":"Assists","deaths_total":"Deaths","3k_rounds_total":'3K', "4k_rounds_total":'4K', "ace_rounds_total":'5K',"damage_total":"Damages","utility_damage_total":"Utility Damages","enemies_flashed_total":"Flashed Ennemies"})
stats = stats.drop(columns={"tick"})
nouvel_ordre_colonnes = [
    'name', 'steamid', 'total_rounds_played', 'Kills', 'Deaths', 'Assists', 
    'K/D', 'Damages', 'ADR', 'KPR', 'HS', 'HS %', '5K', '4K', '3K', 'mvps', 'alive_time_total'
]
stats = stats[nouvel_ordre_colonnes]

# %%
stats
# Out:
#            name            steamid  total_rounds_played  Kills  Deaths  \
# 0     -silentGG  76561198111191178                   30     17      21
# 1  JustAnotherL  76561198264064168                   30     15      23
# 2      OzzieOzz  76561198066661071                   30     19      19
# 3    godofbaldz  76561198259827471                   30     26      18
# 4    ADEODATUSS  76561199198706117                   30     24      18
# 5     BELDIYA00  76561198376612283                   30     27      17
# 6        fykseN  76561198014090099                   30     17      20
# 7      MasaIDK_  76561198358546254                   30     19      24
# 8      Spiritix  76561198173360875                   30     18      19
# 9   3PARABELLUM  76561199074956403                   30     19      22
#
#    Assists   K/D  Damages     ADR   KPR  HS   HS %  5K  4K  3K  mvps  \
# 0        6  0.81     2001   66.70  0.57   8  47.06   0   0   1     3
# 1        7  0.65     1933   64.43  0.50  10  66.67   0   0   1     3
# 2        4  1.00     1892   63.07  0.63   9  47.37   0   1   1     4
# 3        4  1.44     2469   82.30  0.87   3  11.54   0   0   3     3
# 4        2  1.33     2089   69.63  0.80  15  62.50   0   0   1     3
# 5        8  1.59     3213  107.10  0.90  15  55.56   0   1   2     4
# 6        2  0.85     2010   67.00  0.57   7  41.18   0   0   1     1
# 7        8  0.79     2333   77.77  0.63   9  47.37   0   1   0     3
# 8        8  0.95     2000   66.67  0.60   7  38.89   0   0   2     2
# 9        7  0.86     2530   84.33  0.63   9  47.37   0   0   3     4
#
#    alive_time_total
# 0              1333
# 1              1307
# 2              1250
# 3              1155
# 4              1155
# 5              1222
# 6              1207
# 7              1395
# 8              1116
# 9              1495

# %% [markdown]
# ### TABLE FINALE

# %% [markdown]
# #### DF par joueurs

# %%
joueurs = pd.DataFrame()
joueurs['name']  = team_V3.loc[(team_V3['team_clan_name'] == 'zobrux') & (team_V3['tick'] == first_round_tick), 'name']

# %%
Stats_joueurs = joueurs.merge(stats, on='name', how='left')

# %%
Stats_joueurs
# Out:
#          name            steamid  total_rounds_played  Kills  Deaths  Assists  \
# 0   -silentGG  76561198111191178                   30     17      21        6
# 1    OzzieOzz  76561198066661071                   30     19      19        4
# 2  godofbaldz  76561198259827471                   30     26      18        4
# 3   BELDIYA00  76561198376612283                   30     27      17        8
# 4    Spiritix  76561198173360875                   30     18      19        8
#
#     K/D  Damages     ADR   KPR  HS   HS %  5K  4K  3K  mvps  alive_time_total
# 0  0.81     2001   66.70  0.57   8  47.06   0   0   1     3              1333
# 1  1.00     1892   63.07  0.63   9  47.37   0   1   1     4              1250
# 2  1.44     2469   82.30  0.87   3  11.54   0   0   3     3              1155
# 3  1.59     3213  107.10  0.90  15  55.56   0   1   2     4              1222
# 4  0.95     2000   66.67  0.60   7  38.89   0   0   2     2              1116

# %%
flash_assist_count
# Out:
#   assister_name  Flash_assist
# 0    ADEODATUSS             1
# 1  JustAnotherL             1
# 2    godofbaldz             1

# %%
Utils_joueurs = joueurs.merge(stats_utils, on='name', how='left')
Utils_joueurs = Utils_joueurs.merge(flash_assist_count, on='name', how='left')
Utils_joueurs['Flash_assist'] = Utils_joueurs['Flash_assist'].fillna(0).astype(int)

# %%
Utils_joueurs
# Out:
#          name            steamid  Utility Damages  Flashed Ennemies  \
# 0   -silentGG  76561198111191178              175                 7
# 1    OzzieOzz  76561198066661071               75                 5
# 2  godofbaldz  76561198259827471               79                14
# 3   BELDIYA00  76561198376612283              257                 6
# 4    Spiritix  76561198173360875              230                 2
#
#    Flash_assist
# 0             0
# 1             0
# 2             1
# 3             0
# 4             0

# %%
teamplay_stats = joueurs.merge(opening_stats,on='name',how='left')

# %%
teamplay_stats
# Out:
#          name  entry_attempts(T)  entry_successes(T)  %_entry_success(T)  \
# 0   -silentGG                  3                   1                33.0
# 1    OzzieOzz                  2                   1                50.0
# 2  godofbaldz                  6                   4                67.0
# 3   BELDIYA00                  1                   1               100.0
# 4    Spiritix                  3                   2                67.0
#
#    open_attempts(CT)  open_successes(CT)  %_open_success(CT)
# 0                  1                   1               100.0
# 1                  4                   0                 0.0
# 2                  5                   3                60.0
# 3                  2                   2               100.0
# 4                  3                   1                33.0

# %%
teamplay_stats = teamplay_stats.merge(trade_kills_df, on='name',how='left')
teamplay_stats['Trade Kills'] = teamplay_stats['Trade Kills'].fillna(0).astype(int)
teamplay_stats = teamplay_stats.merge(traded_deaths_df, on='name',how='left')
teamplay_stats['Traded Deaths'] = teamplay_stats['Traded Deaths'].fillna(0).astype(int)

# %% [markdown]
# teamplay_stats

# %% [markdown]
# #### DF par maps
